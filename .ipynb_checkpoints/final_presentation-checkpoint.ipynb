# %%
import analysis.analysis_module as am
#!pip install --upgrade /home/bona9/notebook/aaazal

# %%
current_locations = am.get_current_locations_object("2024-02-20, 12:38 ztm")
schedule1 = am.get_schedule_object("2024-02-20 schedule")

# %% [markdown]
# ### Downloading tables:

# %%
current_locations.get_data()
# Out:
#      Lines        Lon VehicleNumber                Time        Lat Brigade
# 0      213  21.102235          1000 2024-02-20 13:14:03  52.222823       3
# 1      213  21.188761          1001 2024-02-20 13:14:00  52.149900       1
# 2      213  21.114889          1002 2024-02-20 10:48:23  52.234758       3
# 3      311  21.077794          1003 2024-02-20 13:14:04  52.243432     503
# 4      213  21.233823          1004 2024-02-20 13:14:04  52.178699       5
# ...    ...        ...           ...                 ...        ...     ...
# 1768   186  20.874670          9951 2024-02-20 01:11:29  52.279209      10
# 1769   193  21.025311          9952 2024-02-20 12:59:25  52.173477       3
# 1770   193  20.875103          9953 2024-02-20 00:14:26  52.279316       3
# 1771   186  20.986816          9954 2024-02-20 12:59:29  52.305592      12
# 1772   114  20.928116          9955 2024-02-20 12:59:17  52.271717       6
#
# [72676 rows x 6 columns]

# %%
schedule1.get_busstops_data()
# Out:
#      zespol slupek        nazwa_zespolu   szer_geo   dlug_geo
# 0      1001     01             Kijowska  52.248455  21.044827
# 1      1001     02             Kijowska  52.249078  21.044443
# 2      1001     03             Kijowska  52.248928  21.044169
# 3      1001     04             Kijowska  52.249969  21.041588
# 4      1001     05             Kijowska  52.250319  21.043861
# ...     ...    ...                  ...        ...        ...
# 7050   R-11     99       ZEA KLESZCZOWA  52.196605  20.922746
# 7051   R-13     00          ZEA STALOWA  52.263590  21.047868
# 7052   R-13     99          ZEA STALOWA  52.263631  21.047922
# 7053   R-19     00  WYDZIAŁ WŁOŚCIAŃSKA  52.271236  20.968586
# 7054   R-19     99  WYDZIAŁ WŁOŚCIAŃSKA  52.271236  20.968496
#
# [7055 rows x 5 columns]

# %%
schedule1.get_lines_from_busstop('1001', '01')
# Out:
#    linia
# 0    102
# 1    123
# 2    125
# 3    138
# 4    146
# 5    147
# 6    166
# 7    202
# 8    509
# 9    N02
# 10   N03
# 11   N21
# 12   N71

# %%
schedule1.get_schedule('1001', '01', '102', 
                       current_locations.get_start_time_of_downloading(), 
                       current_locations.get_end_time_of_downloading())
# Out:
#    brygada                czas
# 26     548 2024-02-20 12:45:00
# 27     545 2024-02-20 13:05:00

# %% [markdown]
# # 1. Buses with speed over 60 - analysis:
#
# ### After 12:38:

# %%
current_locations_bus1 = am.get_current_locations_object("2024-02-20, 12:38 ztm")
ans1_speed = current_locations_bus1.analysis_of_all_buses_speed(60, True)
# Out:
# How many buses exceeded the speed: 51
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_602c2a765bc095ca6f8aa502a603e3c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_602c2a765bc095ca6f8aa502a603e3c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_602c2a765bc095ca6f8aa502a603e3c9 = L.map(
#                 &quot;map_602c2a765bc095ca6f8aa502a603e3c9&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b72881a1dd3b48d0be65e440dad40800 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b72881a1dd3b48d0be65e440dad40800.addTo(map_602c2a765bc095ca6f8aa502a603e3c9);
#
#
#             var marker_3f26c9225a922ccc7be8d219d26b2d11 = L.marker(
#                 [52.4207622, 21.0594923],
#                 {}
#             ).addTo(map_602c2a765bc095ca6f8aa502a603e3c9);
#
#
#         var popup_a80221ab8f7abc370e8632912befb7c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7040d4f631743285a2c01d2451a07584 = $(`&lt;div id=&quot;html_7040d4f631743285a2c01d2451a07584&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_a80221ab8f7abc370e8632912befb7c3.setContent(html_7040d4f631743285a2c01d2451a07584);
#
#
#
#         marker_3f26c9225a922ccc7be8d219d26b2d11.bindPopup(popup_a80221ab8f7abc370e8632912befb7c3)
#         ;
#
#
#
#
#             var marker_144c417a5124f90f725e460b076829e2 = L.marker(
#                 [52.19125085, 21.0746583],
#                 {}
#             ).addTo(map_602c2a765bc095ca6f8aa502a603e3c9);
#
#
#         var popup_2855752ba3b1521c7a3b897455dd461b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c2c3c7e966fc12d0d5dcbd2745b3389e = $(`&lt;div id=&quot;html_c2c3c7e966fc12d0d5dcbd2745b3389e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_2855752ba3b1521c7a3b897455dd461b.setContent(html_c2c3c7e966fc12d0d5dcbd2745b3389e);
#
#
#
#         marker_144c417a5124f90f725e460b076829e2.bindPopup(popup_2855752ba3b1521c7a3b897455dd461b)
#         ;
#
#
#
#
#             var marker_4799c8ec029fd0cc1ef67f824701a109 = L.marker(
#                 [52.209305, 21.0853705],
#                 {}
#             ).addTo(map_602c2a765bc095ca6f8aa502a603e3c9);
#
#
#         var popup_585cd43cefad6954e6dd8a8a8ed818e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_db65849bb2c3219d288bc5d492234697 = $(`&lt;div id=&quot;html_db65849bb2c3219d288bc5d492234697&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_585cd43cefad6954e6dd8a8a8ed818e0.setContent(html_db65849bb2c3219d288bc5d492234697);
#
#
#
#         marker_4799c8ec029fd0cc1ef67f824701a109.bindPopup(popup_585cd43cefad6954e6dd8a8a8ed818e0)
#         ;
#
#
#
#
#             var marker_f574c621e4744ae609af26d62d61f876 = L.marker(
#                 [52.17881645, 21.14088885],
#                 {}
#             ).addTo(map_602c2a765bc095ca6f8aa502a603e3c9);
#
#
#         var popup_4d528baa16a7b5ee3d9455d295b9da4b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_787a37a7d13d293686ef763e40621cf3 = $(`&lt;div id=&quot;html_787a37a7d13d293686ef763e40621cf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_4d528baa16a7b5ee3d9455d295b9da4b.setContent(html_787a37a7d13d293686ef763e40621cf3);
#
#
#
#         marker_f574c621e4744ae609af26d62d61f876.bindPopup(popup_4d528baa16a7b5ee3d9455d295b9da4b)
#         ;
#
#
#
#
#             var marker_b054e1475f560a1f3740e9d883361ea6 = L.marker(
#                 [52.207095949999996, 21.081533999999998],
#                 {}
#             ).addTo(map_602c2a765bc095ca6f8aa502a603e3c9);
#
#
#         var popup_b419494599ad2acc6f5a4b46070f43b2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_13faf5cbdf26d44b756480cdc41615f1 = $(`&lt;div id=&quot;html_13faf5cbdf26d44b756480cdc41615f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_b419494599ad2acc6f5a4b46070f43b2.setContent(html_13faf5cbdf26d44b756480cdc41615f1);
#
#
#
#         marker_b054e1475f560a1f3740e9d883361ea6.bindPopup(popup_b419494599ad2acc6f5a4b46070f43b2)
#         ;
#
#
#
#
#             var marker_36e4918b6e96397d8067e1d6e089c1b0 = L.marker(
#                 [52.2025735, 21.115009999999998],
#                 {}
#             ).addTo(map_602c2a765bc095ca6f8aa502a603e3c9);

# %% [markdown]
# ### After 19:50:

# %%
current_locations_bus2 = am.get_current_locations_object("2024-02-20, 19:50 ztm")
ans2_speed = current_locations_bus2.analysis_of_all_buses_speed(60, True)
# Out:
# How many buses exceeded the speed: 89
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8cfdad9e0f4053b8e74023c20836ad4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8cfdad9e0f4053b8e74023c20836ad4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8cfdad9e0f4053b8e74023c20836ad4 = L.map(
#                 &quot;map_a8cfdad9e0f4053b8e74023c20836ad4&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61c2344c013515947412f7b9db0cb853 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_61c2344c013515947412f7b9db0cb853.addTo(map_a8cfdad9e0f4053b8e74023c20836ad4);
#
#
#             var marker_4540bbb33367bc15b9b43a3461124d9d = L.marker(
#                 [52.168828500000004, 21.0135045],
#                 {}
#             ).addTo(map_a8cfdad9e0f4053b8e74023c20836ad4);
#
#
#         var popup_e4bef8b64da62ebcb099a6de09ff3239 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_22a396cb743089ea466f562b1f42ad9a = $(`&lt;div id=&quot;html_22a396cb743089ea466f562b1f42ad9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_e4bef8b64da62ebcb099a6de09ff3239.setContent(html_22a396cb743089ea466f562b1f42ad9a);
#
#
#
#         marker_4540bbb33367bc15b9b43a3461124d9d.bindPopup(popup_e4bef8b64da62ebcb099a6de09ff3239)
#         ;
#
#
#
#
#             var marker_11a4ac301e8c8197c2cb46fbd695da76 = L.marker(
#                 [52.1618045, 21.0176595],
#                 {}
#             ).addTo(map_a8cfdad9e0f4053b8e74023c20836ad4);
#
#
#         var popup_e97977f2e94ef93e7fcdf661c810fca7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_58f0a3c4804edc72842a379311dc400f = $(`&lt;div id=&quot;html_58f0a3c4804edc72842a379311dc400f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_e97977f2e94ef93e7fcdf661c810fca7.setContent(html_58f0a3c4804edc72842a379311dc400f);
#
#
#
#         marker_11a4ac301e8c8197c2cb46fbd695da76.bindPopup(popup_e97977f2e94ef93e7fcdf661c810fca7)
#         ;
#
#
#
#
#             var marker_b9779f98689e5a02012e5f08b18f6571 = L.marker(
#                 [52.206939500000004, 21.07959],
#                 {}
#             ).addTo(map_a8cfdad9e0f4053b8e74023c20836ad4);
#
#
#         var popup_9eb5a89705ae0849a809ac15c1c2d09f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c611fd370406b9a33ef671b93317b818 = $(`&lt;div id=&quot;html_c611fd370406b9a33ef671b93317b818&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_9eb5a89705ae0849a809ac15c1c2d09f.setContent(html_c611fd370406b9a33ef671b93317b818);
#
#
#
#         marker_b9779f98689e5a02012e5f08b18f6571.bindPopup(popup_9eb5a89705ae0849a809ac15c1c2d09f)
#         ;
#
#
#
#
#             var marker_6c265970fddacb92daa74878429cd83c = L.marker(
#                 [52.2145765, 21.092980500000003],
#                 {}
#             ).addTo(map_a8cfdad9e0f4053b8e74023c20836ad4);
#
#
#         var popup_87e92d5b89fe2cf4686ef0cff5a502bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e4d1933f0dcc9e593fdf3a2384617dad = $(`&lt;div id=&quot;html_e4d1933f0dcc9e593fdf3a2384617dad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_87e92d5b89fe2cf4686ef0cff5a502bc.setContent(html_e4d1933f0dcc9e593fdf3a2384617dad);
#
#
#
#         marker_6c265970fddacb92daa74878429cd83c.bindPopup(popup_87e92d5b89fe2cf4686ef0cff5a502bc)
#         ;
#
#
#
#
#             var marker_84d645da6638f2914fcae0a727ff231b = L.marker(
#                 [52.2136515, 21.092122],
#                 {}
#             ).addTo(map_a8cfdad9e0f4053b8e74023c20836ad4);
#
#
#         var popup_5ae3bbba1becebb6a9114aff21cbc871 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_23a2ad06791c0e771dd4c778158d1c82 = $(`&lt;div id=&quot;html_23a2ad06791c0e771dd4c778158d1c82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_5ae3bbba1becebb6a9114aff21cbc871.setContent(html_23a2ad06791c0e771dd4c778158d1c82);
#
#
#
#         marker_84d645da6638f2914fcae0a727ff231b.bindPopup(popup_5ae3bbba1becebb6a9114aff21cbc871)
#         ;
#
#
#
#
#             var marker_1597b897bfbd10b38cca17320a8a7cde = L.marker(
#                 [52.25041485, 21.14812565],
#                 {}
#             ).addTo(map_a8cfdad9e0f4053b8e74023c20836ad4);

# %% [markdown]
# # Places with a lot of high speeds
# ### After 12:38:

# %%
current_locations_bus1.get_locations_with_lots_overspeeds()
# Out:
# There were 7 areas where at least 3 buses exceded the speed limit.
# Map with these places with aproximate high-speed-steets and with informations
#         how many high-speed measurements where in this area:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61a2002198f96d80c467bef78560f1fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61a2002198f96d80c467bef78560f1fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61a2002198f96d80c467bef78560f1fd = L.map(
#                 &quot;map_61a2002198f96d80c467bef78560f1fd&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d547ad2cba1cd35c691e302e522907be = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d547ad2cba1cd35c691e302e522907be.addTo(map_61a2002198f96d80c467bef78560f1fd);
#
#
#             var poly_line_fa6eb7cf525288fdebd18dcb4d2ffca1 = L.polyline(
#                 [[52.2964164, 20.93439845], [52.29927835, 20.93816005]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_61a2002198f96d80c467bef78560f1fd);
#
#
#             var poly_line_a0acaaa7d37cd5b17bbd8bc8b0888462 = L.polyline(
#                 [[52.29927835, 20.93816005], [52.29907675, 20.9385238]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_61a2002198f96d80c467bef78560f1fd);
#
#
#             var poly_line_074ad6b3978331f5e97461b6adffa2fe = L.polyline(
#                 [[52.29907675, 20.9385238], [52.30068795, 20.9416023]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_61a2002198f96d80c467bef78560f1fd);
#
#
#             var poly_line_5fa668c63d2e2e7f535df7ec0d976cde = L.polyline(
#                 [[52.30068795, 20.9416023], [52.30211655, 20.9422728]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_61a2002198f96d80c467bef78560f1fd);
#
#
#             var poly_line_65f83ff8f5f02c94ee162677649a9720 = L.polyline(
#                 [[52.30211655, 20.9422728], [52.30403445, 20.9457737]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_61a2002198f96d80c467bef78560f1fd);
#
#
#             var poly_line_5a20dd0df388ef7f33f35f27252c46f7 = L.polyline(
#                 [[52.30403445, 20.9457737], [52.306010150000006, 20.950071649999998]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&q

# %% [markdown]
# ### After 19:50:

# %%
current_locations_bus2.get_locations_with_lots_overspeeds()
# Out:
# There were 13 areas where at least 3 buses exceded the speed limit.
# Map with these places with aproximate high-speed-steets and with informations
#         how many high-speed measurements where in this area:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fd9275e733cb49e2c9a840f92169eba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fd9275e733cb49e2c9a840f92169eba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fd9275e733cb49e2c9a840f92169eba = L.map(
#                 &quot;map_5fd9275e733cb49e2c9a840f92169eba&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7bf970d44ea01d26d3b6f4e40f4edcfe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7bf970d44ea01d26d3b6f4e40f4edcfe.addTo(map_5fd9275e733cb49e2c9a840f92169eba);
#
#
#             var poly_line_137ab8456ec7fd9bd60e9edf6e892f75 = L.polyline(
#                 [[52.1687508335, 21.012320666999997], [52.168828500000004, 21.0135045]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5fd9275e733cb49e2c9a840f92169eba);
#
#
#             var poly_line_22b7b800d551960115b8266b865e356c = L.polyline(
#                 [[52.168828500000004, 21.0135045], [52.1679015, 21.016933]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5fd9275e733cb49e2c9a840f92169eba);
#
#
#             var poly_line_92c58920d8386b11ec664ba43f4a22ff = L.polyline(
#                 [[52.1679015, 21.016933], [52.1618045, 21.0176595]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5fd9275e733cb49e2c9a840f92169eba);
#
#
#             var poly_line_9fc3e3b7609ae791b47bd876531aa4f5 = L.polyline(
#                 [[52.1618045, 21.0176595], [52.1605639, 21.01768975]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5fd9275e733cb49e2c9a840f92169eba);
#
#
#             var poly_line_d48781c189791a18b1fc7d4ca7ca3c66 = L.polyline(
#                 [[52.1605639, 21.01768975], [52.1589072, 21.0176915]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5fd9275e733cb49e2c9a840f92169eba);
#
#
#             var poly_line_80afcd304c138d657e3473784b218650 = L.polyline(
#                 [[52.1589072, 21.0176915], [52.166767667, 21.02533425]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&

# %% [markdown]
# # Punctuality:
# ### After 12:38:

# %%
punctuality_object1 = am.get_punctuality_object("2024-02-20, 12:38 ztm", "2024-02-20 schedule")
#punctuality_object1.count_late_buses(True)
punctuality_object1.load_late_buses("out1.csv")
punctuality_object1.analize_delays(4, 0.2, True, True)
# Out:
# Buses were deleyed in 11.58% measured cases.
# Busstops without any delay: 824
# Number of busstops satisfing function's conditions (at least 4 buses): 1532
# Table with the most deleyed busstops:
#      zespol  slupek               nazwa_zespolu   szer_geo   dlug_geo  late  \
# 4676   4038       1  Komitetu Obrony Robotników  52.178995  20.978165     5
# 4789   4085       2                    Radarowa  52.188762  20.962959     7
# 4675   4037       4                     Sasanki  52.184058  20.977725     7
# 3092   3027      52                       Dolna  52.202896  21.034283    11
# 4595   4011       6                       Hynka  52.190608  20.957315     5
# 5003   4200       1     Lotnisko Chopina-Odloty  52.172074  20.973369     5
# 4793   4087       2                   Orzechowa  52.192147  20.949007     4
#
#       all   percent
# 4676    5  1.000000
# 4789    7  1.000000
# 4675    8  0.875000
# 3092   13  0.846154
# 4595    6  0.833333
# 5003    6  0.833333
# 4793    5  0.800000
# Map with delays:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_246e1d1a7fed1f6e5f67ccb97ed06149 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_246e1d1a7fed1f6e5f67ccb97ed06149&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_246e1d1a7fed1f6e5f67ccb97ed06149 = L.map(
#                 &quot;map_246e1d1a7fed1f6e5f67ccb97ed06149&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef59241b8bf4f79aee40a98797866d4d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ef59241b8bf4f79aee40a98797866d4d.addTo(map_246e1d1a7fed1f6e5f67ccb97ed06149);
#
#
#             var circle_marker_ecdcf8baa90dd8664969aed65102cda0 = L.circleMarker(
#                 [52.178995, 20.978165],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ba4a00&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_246e1d1a7fed1f6e5f67ccb97ed06149);
#
#
#         var popup_f8b4e0bd75cd2a39643f109f19e822f8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1ba0cb9e0d1a254cf56c969059af8c5f = $(`&lt;div id=&quot;html_1ba0cb9e0d1a254cf56c969059af8c5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1.0&lt;/div&gt;`)[0];
#                 popup_f8b4e0bd75cd2a39643f109f19e822f8.setContent(html_1ba0cb9e0d1a254cf56c969059af8c5f);
#
#
#
#         circle_marker_ecdcf8baa90dd8664969aed65102cda0.bindPopup(popup_f8b4e0bd75cd2a39643f109f19e822f8)
#         ;
#
#
#
#
#             var circle_marker_2dee6fe8145206b94b47b64954b8256c = L.circleMarker(
#                 [52.188762, 20.962959],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ba4a00&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_246e1d1a7fed1f6e5f67ccb97ed06149);
#
#
#         var popup_a753055eefcdcd74cf0761362177caaf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3c1104a1a1ca327b5f91925cac3a4eb0 = $(`&lt;div id=&quot;html_3c1104a1a1ca327b5f91925cac3a4eb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1.0&lt;/div&gt;`)[0];
#                 popup_a753055eefcdcd74cf0761362177caaf.setContent(html_3c1104a1a1ca327b5f91925cac3a4eb0);
#
#
#
#         circle_marker_2dee6fe8145206b94b47b64954b8256c.bindPopup(popup_a753055eefcdcd74cf0761362177caaf)
#         ;
#
#
#
#
#             var circle_marker_3d62afb184f133d4bd15aed29b81dd58 = L.circleMarker(
#                 [52.184058, 20.977725],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_246e1d1a7fed1f6e5f67ccb97ed06149);
#
#
#         var popup_b412fb361c7166b523755ea1fbc1be51 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d6184d8aec624aac9d4a9bcc57437faa = $(`&lt;div id=&quot;html_d6184d8aec624aac9d4a9bcc57437faa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.875&lt;/div&gt;`)[0];
#                 popup_b412fb361c7166b523755ea1fbc1be51.setContent(html_d6184d8aec624aac9d4a9bcc57437faa);
#
#
#
#         circle_marker_3d62afb184f133d4bd15aed29b81dd58.bindPopup(popup_b412fb361c7166b523755ea1fbc1be51)
#         ;
#
#
#
#
#             var circle_marker_540ea194f7e371075609c2b0b4f87d2e = L.circleMarker(
#                 [52.202896, 21.034283],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;roun

# %%
punctuality_object1.get_all_busstops()
# Out:
#       Unnamed: 0 zespol  slupek        nazwa_zespolu   szer_geo   dlug_geo  \
# 0              0   1001       1             Kijowska  52.248455  21.044827
# 1              1   1001       2             Kijowska  52.249078  21.044443
# 2              2   1001       3             Kijowska  52.248928  21.044169
# 3              3   1001       4             Kijowska  52.249969  21.041588
# 4              4   1001       5             Kijowska  52.250319  21.043861
# ...          ...    ...     ...                  ...        ...        ...
# 7050        7050   R-11      99       ZEA KLESZCZOWA  52.196605  20.922746
# 7051        7051   R-13       0          ZEA STALOWA  52.263590  21.047868
# 7052        7052   R-13      99          ZEA STALOWA  52.263631  21.047922
# 7053        7053   R-19       0  WYDZIAŁ WŁOŚCIAŃSKA  52.271236  20.968586
# 7054        7054   R-19      99  WYDZIAŁ WŁOŚCIAŃSKA  52.271236  20.968496
#
#       late  all
# 0        0   18
# 1        2    8
# 2        0    0
# 3        0    0
# 4        0    0
# ...    ...  ...
# 7050     0    0
# 7051     0    1
# 7052     0    0
# 7053     0    0
# 7054     0    0
#
# [7055 rows x 8 columns]

# %% [markdown]
# ### After 19:50:

# %%
punctuality_object2 = am.get_punctuality_object("2024-02-20, 19:50 ztm", "2024-02-20 schedule")
#punctuality_object2.count_late_buses(True)
punctuality_object2.load_late_buses("out2.csv")
punctuality_object2.analize_delays(4, 0.2, True, True)
# Out:
# Buses were deleyed in 8.52% measured cases.
# Busstops without any delay: 950
# Number of busstops satisfing function's conditions (at least 4 buses): 1666
# Table with the most deleyed busstops:
#      zespol  slupek         nazwa_zespolu   szer_geo   dlug_geo  late  all  \
# 5234   4348       1   PKP Żwirki i Wigury  52.193570  20.981904     6    8
# 3366   3126       2              Tagore'a  52.195369  21.007382     3    5
# 4100   3701      71                 Zgoda  52.074815  21.029482     3    5
# 3477   3168       1  Kolejka Piaseczyńska  52.069128  21.025004     3    5
# 3700   3255       2            Miłobędzka  52.197028  20.992109     3    5
# 6866   7054       3        Park Traugutta  52.258470  21.002556     3    5
# 6497   6407       2      Łomianki-Centrum  52.339728  20.890891     3    5
#
#       percent
# 5234     0.75
# 3366     0.60
# 4100     0.60
# 3477     0.60
# 3700     0.60
# 6866     0.60
# 6497     0.60
# Map with delays:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ac6facca613da3c62c471c31e83b318 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ac6facca613da3c62c471c31e83b318&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ac6facca613da3c62c471c31e83b318 = L.map(
#                 &quot;map_1ac6facca613da3c62c471c31e83b318&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39dafa60397547510560baecc8448793 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_39dafa60397547510560baecc8448793.addTo(map_1ac6facca613da3c62c471c31e83b318);
#
#
#             var circle_marker_a5ea931a3db37d1da3a889ede7506e06 = L.circleMarker(
#                 [52.19357, 20.981904],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1ac6facca613da3c62c471c31e83b318);
#
#
#         var popup_c7cc79f4dddd0c4d9f88478873bab888 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f2dad336af3198473ccfd5f9ed797048 = $(`&lt;div id=&quot;html_f2dad336af3198473ccfd5f9ed797048&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.75&lt;/div&gt;`)[0];
#                 popup_c7cc79f4dddd0c4d9f88478873bab888.setContent(html_f2dad336af3198473ccfd5f9ed797048);
#
#
#
#         circle_marker_a5ea931a3db37d1da3a889ede7506e06.bindPopup(popup_c7cc79f4dddd0c4d9f88478873bab888)
#         ;
#
#
#
#
#             var circle_marker_8c9d584a468a84ac9f1fbd74418097be = L.circleMarker(
#                 [52.195369, 21.007382],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1ac6facca613da3c62c471c31e83b318);
#
#
#         var popup_fa46effa70bbdb0df60d55479e6b9b15 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53ab6f976adce25fffdc7e4b91c9e685 = $(`&lt;div id=&quot;html_53ab6f976adce25fffdc7e4b91c9e685&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.6&lt;/div&gt;`)[0];
#                 popup_fa46effa70bbdb0df60d55479e6b9b15.setContent(html_53ab6f976adce25fffdc7e4b91c9e685);
#
#
#
#         circle_marker_8c9d584a468a84ac9f1fbd74418097be.bindPopup(popup_fa46effa70bbdb0df60d55479e6b9b15)
#         ;
#
#
#
#
#             var circle_marker_0ed214bdd01d410efb7af8478e7fdce2 = L.circleMarker(
#                 [52.074815, 21.029482],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1ac6facca613da3c62c471c31e83b318);
#
#
#         var popup_1aedf103fe8dbf6dd45ac71663288c4e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5249e984b8dcec802f5a10d48a00c14e = $(`&lt;div id=&quot;html_5249e984b8dcec802f5a10d48a00c14e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.6&lt;/div&gt;`)[0];
#                 popup_1aedf103fe8dbf6dd45ac71663288c4e.setContent(html_5249e984b8dcec802f5a10d48a00c14e);
#
#
#
#         circle_marker_0ed214bdd01d410efb7af8478e7fdce2.bindPopup(popup_1aedf103fe8dbf6dd45ac71663288c4e)
#         ;
#
#
#
#
#             var circle_marker_bc0f19b2ea8771c27a7f2e26a976b9e0 = L.circleMarker(
#                 [52.069128, 21.025004],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&

# %% [markdown]
# ## Which busstops have less delays at after 12:38 than after 19:50 - analysis

# %%
punctuality_object1.get_better_busstops(punctuality_object2)
# Out:
# For "2024-02-20, 12:38 ztm" there are 337 busstops with better delay rate
# than for "2024-02-20, 19:50 ztm"
#
# Table with the best difference busstops:
#       slupek           nazwa_zespolu      diff
# 3150       2                   Vogla  0.500000
# 4845       2           Sosnkowskiego  0.500000
# 5337       1  Połczyńska-parking P+R  0.444444
# 4817       2             Wapowskiego  0.400000
# 6497       2        Łomianki-Centrum  0.400000
# 5867       1                Lazurowa  0.375000
# 2605       3                 Torfowa  0.375000
# The map shows busstops with smaller number of delays for our object
# green point - small difference in delay rate
# red point - big difference
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e85a245c493c232cf02c5e82f5dfb9a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e85a245c493c232cf02c5e82f5dfb9a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e85a245c493c232cf02c5e82f5dfb9a = L.map(
#                 &quot;map_3e85a245c493c232cf02c5e82f5dfb9a&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc119c49ab9fe8a9f15f1af70b5ae174 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fc119c49ab9fe8a9f15f1af70b5ae174.addTo(map_3e85a245c493c232cf02c5e82f5dfb9a);
#
#
#             var circle_marker_a77de4f5ec57c2be71cb9cd1a4908945 = L.circleMarker(
#                 [52.160352, 21.086672],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f39c12&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3e85a245c493c232cf02c5e82f5dfb9a);
#
#
#         var popup_4bc1bc1e0ce2f995ee1ab52a995b3a03 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9e4829cf1f1aa569e03597155020cace = $(`&lt;div id=&quot;html_9e4829cf1f1aa569e03597155020cace&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.5&lt;/div&gt;`)[0];
#                 popup_4bc1bc1e0ce2f995ee1ab52a995b3a03.setContent(html_9e4829cf1f1aa569e03597155020cace);
#
#
#
#         circle_marker_a77de4f5ec57c2be71cb9cd1a4908945.bindPopup(popup_4bc1bc1e0ce2f995ee1ab52a995b3a03)
#         ;
#
#
#
#
#             var circle_marker_bc67fca822c99aaaa76c0f8827d59170 = L.circleMarker(
#                 [52.189665, 20.88677],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f39c12&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3e85a245c493c232cf02c5e82f5dfb9a);
#
#
#         var popup_78da037dd3a1492b21f4d472b5e7ccd9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c38157d0623ed9a0ed447c0c3f22cd42 = $(`&lt;div id=&quot;html_c38157d0623ed9a0ed447c0c3f22cd42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.5&lt;/div&gt;`)[0];
#                 popup_78da037dd3a1492b21f4d472b5e7ccd9.setContent(html_c38157d0623ed9a0ed447c0c3f22cd42);
#
#
#
#         circle_marker_bc67fca822c99aaaa76c0f8827d59170.bindPopup(popup_78da037dd3a1492b21f4d472b5e7ccd9)
#         ;
#
#
#
#
#             var circle_marker_296be36527dfc0939e83756c9359767a = L.circleMarker(
#                 [52.221784, 20.923929],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f1c40f&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3e85a245c493c232cf02c5e82f5dfb9a);
#
#
#         var popup_274e8f6587b89610be76c9e138e3dd61 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3353a47794787113623801d42a72021 = $(`&lt;div id=&quot;html_f3353a47794787113623801d42a72021&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.4444444444444444&lt;/div&gt;`)[0];
#                 popup_274e8f6587b89610be76c9e138e3dd61.setContent(html_f3353a47794787113623801d42a72021);
#
#
#
#         circle_marker_296be36527dfc0939e83756c9359767a.bindPopup(popup_274e8f6587b89610be76c9e138e3dd61)
#         ;
#
#
#
#
#             var circle_marker_c749ba765723c4b7d156ba4baf0b30b3 = L.circleMarker(
#                 [52.190677, 20.892005],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f1c40f&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;

# %%
punctuality_object2.get_better_busstops(punctuality_object1)
# Out:
# For "2024-02-20, 19:50 ztm" there are 511 busstops with better delay rate
# than for "2024-02-20, 12:38 ztm"
#
# Table with the best difference busstops:
#       slupek               nazwa_zespolu      diff
# 4595       6                       Hynka  0.833333
# 4676       1  Komitetu Obrony Robotników  0.800000
# 4793       2                   Orzechowa  0.800000
# 5003       1     Lotnisko Chopina-Odloty  0.722222
# 3402       1             Miklaszewskiego  0.666667
# 3985       1             Warchałowskiego  0.666667
# 3343       1                Ursynów Płn.  0.666667
# The map shows busstops with smaller number of delays for our object
# green point - small difference in delay rate
# red point - big difference
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b610221209c01e95e8cd85c3b2c9684c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b610221209c01e95e8cd85c3b2c9684c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b610221209c01e95e8cd85c3b2c9684c = L.map(
#                 &quot;map_b610221209c01e95e8cd85c3b2c9684c&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49c553619a9696e2fc9ade350a072d7f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_49c553619a9696e2fc9ade350a072d7f.addTo(map_b610221209c01e95e8cd85c3b2c9684c);
#
#
#             var circle_marker_de386753d8b8b89b68d48728f997f3c7 = L.circleMarker(
#                 [52.190608, 20.957315],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b610221209c01e95e8cd85c3b2c9684c);
#
#
#         var popup_0f1afc549a4a2391fc05dc418efef401 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be5d7fedbecce27f32ef0e99e93e70b8 = $(`&lt;div id=&quot;html_be5d7fedbecce27f32ef0e99e93e70b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.8333333333333334&lt;/div&gt;`)[0];
#                 popup_0f1afc549a4a2391fc05dc418efef401.setContent(html_be5d7fedbecce27f32ef0e99e93e70b8);
#
#
#
#         circle_marker_de386753d8b8b89b68d48728f997f3c7.bindPopup(popup_0f1afc549a4a2391fc05dc418efef401)
#         ;
#
#
#
#
#             var circle_marker_a108056322f4afed06d76df5ba19c67a = L.circleMarker(
#                 [52.178995, 20.978165],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b610221209c01e95e8cd85c3b2c9684c);
#
#
#         var popup_944c734b5eb7cec1de52db3512c5132c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3fdf6bd4537629a4609d9d9f07f33b78 = $(`&lt;div id=&quot;html_3fdf6bd4537629a4609d9d9f07f33b78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.8&lt;/div&gt;`)[0];
#                 popup_944c734b5eb7cec1de52db3512c5132c.setContent(html_3fdf6bd4537629a4609d9d9f07f33b78);
#
#
#
#         circle_marker_a108056322f4afed06d76df5ba19c67a.bindPopup(popup_944c734b5eb7cec1de52db3512c5132c)
#         ;
#
#
#
#
#             var circle_marker_9a4fbd2a69919059eadf5f52229ab46a = L.circleMarker(
#                 [52.192147, 20.949007],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b610221209c01e95e8cd85c3b2c9684c);
#
#
#         var popup_9d618285b3e319f7769a314f566dd16f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f5e8fd5e2a9495ea9391e166b247ba90 = $(`&lt;div id=&quot;html_f5e8fd5e2a9495ea9391e166b247ba90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.8&lt;/div&gt;`)[0];
#                 popup_9d618285b3e319f7769a314f566dd16f.setContent(html_f5e8fd5e2a9495ea9391e166b247ba90);
#
#
#
#         circle_marker_9a4fbd2a69919059eadf5f52229ab46a.bindPopup(popup_9d618285b3e319f7769a314f566dd16f)
#         ;
#
#
#
#
#             var circle_marker_f253528e79a52edc5a97e951161a687f = L.circleMarker(
#                 [52.172074, 20.973369],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot
