# %%
import analysis.analysis_module as am
#!pip install --upgrade /home/bona9/notebook/aaazal

# %% [markdown]
# # 1. Buses with speed over 60 - analysis:
#
# ### After 12:38:

# %%
current_locations_bus1 = am.get_current_locations_object("2024-02-20, 12:38 ztm")
ans1_speed = current_locations_bus1.analysis_of_all_buses_speed(60, True)
# Out:
# How many buses exceeded the speed: 51
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e62f8a11ec963281fad6d8cf65b4dd5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e62f8a11ec963281fad6d8cf65b4dd5e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e62f8a11ec963281fad6d8cf65b4dd5e = L.map(
#                 &quot;map_e62f8a11ec963281fad6d8cf65b4dd5e&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fb6d35a763b9bf74bf03b212db924db3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fb6d35a763b9bf74bf03b212db924db3.addTo(map_e62f8a11ec963281fad6d8cf65b4dd5e);
#
#
#             var marker_a17367415e1e8a67e3f284ef434a5a4f = L.marker(
#                 [52.4207622, 21.0594923],
#                 {}
#             ).addTo(map_e62f8a11ec963281fad6d8cf65b4dd5e);
#
#
#         var popup_90ee01c945d9cc57b2dc9b7e151a8898 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_69ceefe47b964fe4d2bf711e06c01c01 = $(`&lt;div id=&quot;html_69ceefe47b964fe4d2bf711e06c01c01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_90ee01c945d9cc57b2dc9b7e151a8898.setContent(html_69ceefe47b964fe4d2bf711e06c01c01);
#
#
#
#         marker_a17367415e1e8a67e3f284ef434a5a4f.bindPopup(popup_90ee01c945d9cc57b2dc9b7e151a8898)
#         ;
#
#
#
#
#             var marker_fa698a91c6c41c2e6841b55468aa99b6 = L.marker(
#                 [52.19125085, 21.0746583],
#                 {}
#             ).addTo(map_e62f8a11ec963281fad6d8cf65b4dd5e);
#
#
#         var popup_d7c97a27b984702d00dc1bec36d30081 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5b779231dfbc9296be4113a88ab5986 = $(`&lt;div id=&quot;html_d5b779231dfbc9296be4113a88ab5986&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_d7c97a27b984702d00dc1bec36d30081.setContent(html_d5b779231dfbc9296be4113a88ab5986);
#
#
#
#         marker_fa698a91c6c41c2e6841b55468aa99b6.bindPopup(popup_d7c97a27b984702d00dc1bec36d30081)
#         ;
#
#
#
#
#             var marker_7f37a29422673d401f26c1e263c28c0e = L.marker(
#                 [52.209305, 21.0853705],
#                 {}
#             ).addTo(map_e62f8a11ec963281fad6d8cf65b4dd5e);
#
#
#         var popup_4d69bc483c54ded212aeb21529613947 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d0c44ec42e69387ba63f36230236bb96 = $(`&lt;div id=&quot;html_d0c44ec42e69387ba63f36230236bb96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_4d69bc483c54ded212aeb21529613947.setContent(html_d0c44ec42e69387ba63f36230236bb96);
#
#
#
#         marker_7f37a29422673d401f26c1e263c28c0e.bindPopup(popup_4d69bc483c54ded212aeb21529613947)
#         ;
#
#
#
#
#             var marker_911460c4eff1de05d1fc0c6757e9c892 = L.marker(
#                 [52.17881645, 21.14088885],
#                 {}
#             ).addTo(map_e62f8a11ec963281fad6d8cf65b4dd5e);
#
#
#         var popup_9175e615bd435af652821e92dced01c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a81000ae8d2ca4edb6eddc44a4b4db2 = $(`&lt;div id=&quot;html_5a81000ae8d2ca4edb6eddc44a4b4db2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_9175e615bd435af652821e92dced01c0.setContent(html_5a81000ae8d2ca4edb6eddc44a4b4db2);
#
#
#
#         marker_911460c4eff1de05d1fc0c6757e9c892.bindPopup(popup_9175e615bd435af652821e92dced01c0)
#         ;
#
#
#
#
#             var marker_617f1172d82267915176b3c5f119ab99 = L.marker(
#                 [52.207095949999996, 21.081533999999998],
#                 {}
#             ).addTo(map_e62f8a11ec963281fad6d8cf65b4dd5e);
#
#
#         var popup_72ab69288f147eced9fe86c3a06e655b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0372c02b13e759cfdf8d3f508b5776eb = $(`&lt;div id=&quot;html_0372c02b13e759cfdf8d3f508b5776eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_72ab69288f147eced9fe86c3a06e655b.setContent(html_0372c02b13e759cfdf8d3f508b5776eb);
#
#
#
#         marker_617f1172d82267915176b3c5f119ab99.bindPopup(popup_72ab69288f147eced9fe86c3a06e655b)
#         ;
#
#
#
#
#             var marker_b807743b46d047c49f69718bdd0eddc7 = L.marker(
#                 [52.2025735, 21.115009999999998],
#                 {}
#             ).addTo(map_e62f8a11ec963281fad6d8cf65b4dd5e);

# %% [markdown]
# ### After 19:50:

# %%
current_locations_bus2 = am.get_current_locations_object("2024-02-20, 19:50 ztm")
ans2_speed = current_locations_bus2.analysis_of_all_buses_speed(60, True)
# Out:
# How many buses exceeded the speed: 89
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4610618315c645da6504136e0e358cdd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4610618315c645da6504136e0e358cdd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4610618315c645da6504136e0e358cdd = L.map(
#                 &quot;map_4610618315c645da6504136e0e358cdd&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c5a08481fe79a8a4c43ffbacff18db1d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c5a08481fe79a8a4c43ffbacff18db1d.addTo(map_4610618315c645da6504136e0e358cdd);
#
#
#             var marker_9a510b80116c5383bbf358873edd42c8 = L.marker(
#                 [52.168828500000004, 21.0135045],
#                 {}
#             ).addTo(map_4610618315c645da6504136e0e358cdd);
#
#
#         var popup_b51832e8dbf5309928dd496ee49fe512 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_40ac02025cd89d286edc3eaacf976aa7 = $(`&lt;div id=&quot;html_40ac02025cd89d286edc3eaacf976aa7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_b51832e8dbf5309928dd496ee49fe512.setContent(html_40ac02025cd89d286edc3eaacf976aa7);
#
#
#
#         marker_9a510b80116c5383bbf358873edd42c8.bindPopup(popup_b51832e8dbf5309928dd496ee49fe512)
#         ;
#
#
#
#
#             var marker_56eccf836f5b84b6e9bdde2707f34987 = L.marker(
#                 [52.1618045, 21.0176595],
#                 {}
#             ).addTo(map_4610618315c645da6504136e0e358cdd);
#
#
#         var popup_5c6fe2e9e56ad793a8baf1ef48b525fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c6914b5b257f16339905d0ba64084b7 = $(`&lt;div id=&quot;html_0c6914b5b257f16339905d0ba64084b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_5c6fe2e9e56ad793a8baf1ef48b525fc.setContent(html_0c6914b5b257f16339905d0ba64084b7);
#
#
#
#         marker_56eccf836f5b84b6e9bdde2707f34987.bindPopup(popup_5c6fe2e9e56ad793a8baf1ef48b525fc)
#         ;
#
#
#
#
#             var marker_bf5ba06c68bff568c22d418d2966bb27 = L.marker(
#                 [52.206939500000004, 21.07959],
#                 {}
#             ).addTo(map_4610618315c645da6504136e0e358cdd);
#
#
#         var popup_e5a47ffbe591621018620c9af8434815 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f0778c48ab1977df06bd33b36e91c9bd = $(`&lt;div id=&quot;html_f0778c48ab1977df06bd33b36e91c9bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_e5a47ffbe591621018620c9af8434815.setContent(html_f0778c48ab1977df06bd33b36e91c9bd);
#
#
#
#         marker_bf5ba06c68bff568c22d418d2966bb27.bindPopup(popup_e5a47ffbe591621018620c9af8434815)
#         ;
#
#
#
#
#             var marker_c80f77dd10d89874b284a4b9bfe477df = L.marker(
#                 [52.2145765, 21.092980500000003],
#                 {}
#             ).addTo(map_4610618315c645da6504136e0e358cdd);
#
#
#         var popup_803dc4a9b3a5063f3f0a56e1067de1f0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_013cc6ef6d751984617c59839359adf1 = $(`&lt;div id=&quot;html_013cc6ef6d751984617c59839359adf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_803dc4a9b3a5063f3f0a56e1067de1f0.setContent(html_013cc6ef6d751984617c59839359adf1);
#
#
#
#         marker_c80f77dd10d89874b284a4b9bfe477df.bindPopup(popup_803dc4a9b3a5063f3f0a56e1067de1f0)
#         ;
#
#
#
#
#             var marker_08f140fc27cbf21844a4624c861f588c = L.marker(
#                 [52.2136515, 21.092122],
#                 {}
#             ).addTo(map_4610618315c645da6504136e0e358cdd);
#
#
#         var popup_f8df9b901c86ac410e76b19f542f1e3a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48957e5bd19e7117482d3aaf10ea6f92 = $(`&lt;div id=&quot;html_48957e5bd19e7117482d3aaf10ea6f92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_f8df9b901c86ac410e76b19f542f1e3a.setContent(html_48957e5bd19e7117482d3aaf10ea6f92);
#
#
#
#         marker_08f140fc27cbf21844a4624c861f588c.bindPopup(popup_f8df9b901c86ac410e76b19f542f1e3a)
#         ;
#
#
#
#
#             var marker_22eba6374e52d27a62114f8e8ad21338 = L.marker(
#                 [52.25041485, 21.14812565],
#                 {}
#             ).addTo(map_4610618315c645da6504136e0e358cdd);

# %% [markdown]
# # Places with a lot of high speeds
# ### After 12:38:

# %%
current_locations_bus1.get_locations_with_lots_overspeeds()
# Out:
# There were 7 areas where at least 3 buses exceded the speed limit.
# Map with these places with aproximate high-speed-steets and with informations
#         how many high-speed measurements where in this area:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b66f85b9bf1b10fb5f8a0674e2b4edf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b66f85b9bf1b10fb5f8a0674e2b4edf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b66f85b9bf1b10fb5f8a0674e2b4edf = L.map(
#                 &quot;map_0b66f85b9bf1b10fb5f8a0674e2b4edf&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22a8ae79381f009828d6a5afeed12554 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_22a8ae79381f009828d6a5afeed12554.addTo(map_0b66f85b9bf1b10fb5f8a0674e2b4edf);
#
#
#             var poly_line_2289fddde2c3e3b8c79628cbda75dad3 = L.polyline(
#                 [[52.2964164, 20.93439845], [52.29927835, 20.93816005]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b66f85b9bf1b10fb5f8a0674e2b4edf);
#
#
#             var poly_line_b6c6fbb3e2383f6c409c2c88f00997ff = L.polyline(
#                 [[52.29927835, 20.93816005], [52.29907675, 20.9385238]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b66f85b9bf1b10fb5f8a0674e2b4edf);
#
#
#             var poly_line_455b3f7461e2b69eca989db62548d629 = L.polyline(
#                 [[52.29907675, 20.9385238], [52.30068795, 20.9416023]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b66f85b9bf1b10fb5f8a0674e2b4edf);
#
#
#             var poly_line_1e5756f6b570f14aa610563acc8fd888 = L.polyline(
#                 [[52.30068795, 20.9416023], [52.30211655, 20.9422728]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b66f85b9bf1b10fb5f8a0674e2b4edf);
#
#
#             var poly_line_52ec22807d406594cf438d8ca50e204b = L.polyline(
#                 [[52.30211655, 20.9422728], [52.30403445, 20.9457737]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b66f85b9bf1b10fb5f8a0674e2b4edf);
#
#
#             var poly_line_b69bdbabe146df49ca1342bacd8a35b7 = L.polyline(
#                 [[52.30403445, 20.9457737], [52.306010150000006, 20.950071649999998]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&q

# %% [markdown]
# ### After 19:50:

# %%
current_locations_bus2.get_locations_with_lots_overspeeds()
# Out:
# There were 13 areas where at least 3 buses exceded the speed limit.
# Map with these places with aproximate high-speed-steets and with informations
#         how many high-speed measurements where in this area:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b59662958fc6c6ea3bbf4af38e377bca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b59662958fc6c6ea3bbf4af38e377bca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b59662958fc6c6ea3bbf4af38e377bca = L.map(
#                 &quot;map_b59662958fc6c6ea3bbf4af38e377bca&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19c84125f12b5bc5c650d6cc90012028 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_19c84125f12b5bc5c650d6cc90012028.addTo(map_b59662958fc6c6ea3bbf4af38e377bca);
#
#
#             var poly_line_f5f9e91d99ae38f9a28f9465b9145770 = L.polyline(
#                 [[52.1687508335, 21.012320666999997], [52.168828500000004, 21.0135045]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b59662958fc6c6ea3bbf4af38e377bca);
#
#
#             var poly_line_a08f9cb194f1a0d62441a5cc232a501e = L.polyline(
#                 [[52.168828500000004, 21.0135045], [52.1679015, 21.016933]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b59662958fc6c6ea3bbf4af38e377bca);
#
#
#             var poly_line_57db4dc8cd81d984a9094a2e6c04a9ef = L.polyline(
#                 [[52.1679015, 21.016933], [52.1618045, 21.0176595]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b59662958fc6c6ea3bbf4af38e377bca);
#
#
#             var poly_line_3921ff70969a16d6bed1936576ea3fa2 = L.polyline(
#                 [[52.1618045, 21.0176595], [52.1605639, 21.01768975]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b59662958fc6c6ea3bbf4af38e377bca);
#
#
#             var poly_line_15668b2d6e8d248423dd377763f7e7c7 = L.polyline(
#                 [[52.1605639, 21.01768975], [52.1589072, 21.0176915]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b59662958fc6c6ea3bbf4af38e377bca);
#
#
#             var poly_line_5531f3d7f217181db240013a40b0e12b = L.polyline(
#                 [[52.1589072, 21.0176915], [52.166767667, 21.02533425]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&

# %% [markdown]
# # Punctuality:
# ### After 12:38:

# %%
punctuality_object1 = am.get_punctuality_object("2024-02-20, 12:38 ztm", "2024-02-20 schedule")
#punctuality_object1.count_late_buses(True)
punctuality_object1.load_late_buses("out1.csv")
punctuality_object1.analize_delays(4, 0.5, True, True)
# Out:
# Buses were deleyed in 11.58% measured cases.
# Busstops without any delay: 824
# Number of busstops satisfing function's conditions (at least 4 buses): 1532
# Table with the most deleyed busstops:
#      zespol  slupek               nazwa_zespolu   szer_geo   dlug_geo  late  \
# 4676   4038       1  Komitetu Obrony Robotników  52.178995  20.978165     5
# 4789   4085       2                    Radarowa  52.188762  20.962959     7
# 4675   4037       4                     Sasanki  52.184058  20.977725     7
# 3092   3027      52                       Dolna  52.202896  21.034283    11
# 4595   4011       6                       Hynka  52.190608  20.957315     5
# 5003   4200       1     Lotnisko Chopina-Odloty  52.172074  20.973369     5
# 4793   4087       2                   Orzechowa  52.192147  20.949007     4
#
#       all   percent
# 4676    5  1.000000
# 4789    7  1.000000
# 4675    8  0.875000
# 3092   13  0.846154
# 4595    6  0.833333
# 5003    6  0.833333
# 4793    5  0.800000
# Map with delays:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69e97cdfc6ce83712651fb79234d585f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69e97cdfc6ce83712651fb79234d585f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_69e97cdfc6ce83712651fb79234d585f = L.map(
#                 &quot;map_69e97cdfc6ce83712651fb79234d585f&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7725c56ffe37ce495b0844a79328b70d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7725c56ffe37ce495b0844a79328b70d.addTo(map_69e97cdfc6ce83712651fb79234d585f);
#
#
#             var circle_marker_da8f317e17ceb18157911b1c306c4693 = L.circleMarker(
#                 [52.178995, 20.978165],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ba4a00&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_69e97cdfc6ce83712651fb79234d585f);
#
#
#         var popup_9aac70048c4008a635be7e0b2b20718a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_44af9a18b9a9a0692d5870fbbffb9d5f = $(`&lt;div id=&quot;html_44af9a18b9a9a0692d5870fbbffb9d5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1.0&lt;/div&gt;`)[0];
#                 popup_9aac70048c4008a635be7e0b2b20718a.setContent(html_44af9a18b9a9a0692d5870fbbffb9d5f);
#
#
#
#         circle_marker_da8f317e17ceb18157911b1c306c4693.bindPopup(popup_9aac70048c4008a635be7e0b2b20718a)
#         ;
#
#
#
#
#             var circle_marker_7f19c3985f97111a97700d160a35834a = L.circleMarker(
#                 [52.188762, 20.962959],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ba4a00&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_69e97cdfc6ce83712651fb79234d585f);
#
#
#         var popup_efd7e44c04bdda0c0cc1c59458e00d9b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4b055a5a8fbcf4ee0e147d2c76df7ee3 = $(`&lt;div id=&quot;html_4b055a5a8fbcf4ee0e147d2c76df7ee3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1.0&lt;/div&gt;`)[0];
#                 popup_efd7e44c04bdda0c0cc1c59458e00d9b.setContent(html_4b055a5a8fbcf4ee0e147d2c76df7ee3);
#
#
#
#         circle_marker_7f19c3985f97111a97700d160a35834a.bindPopup(popup_efd7e44c04bdda0c0cc1c59458e00d9b)
#         ;
#
#
#
#
#             var circle_marker_70ab6404a12e06c6790a9c7a4d2faf0a = L.circleMarker(
#                 [52.184058, 20.977725],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_69e97cdfc6ce83712651fb79234d585f);
#
#
#         var popup_c715226b1ff0589eb56812e9e138122c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_54cd1500a1e70da16e8dd7237afc2d7f = $(`&lt;div id=&quot;html_54cd1500a1e70da16e8dd7237afc2d7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.875&lt;/div&gt;`)[0];
#                 popup_c715226b1ff0589eb56812e9e138122c.setContent(html_54cd1500a1e70da16e8dd7237afc2d7f);
#
#
#
#         circle_marker_70ab6404a12e06c6790a9c7a4d2faf0a.bindPopup(popup_c715226b1ff0589eb56812e9e138122c)
#         ;
#
#
#
#
#             var circle_marker_e1dd93220b416f265112f807903b74c8 = L.circleMarker(
#                 [52.202896, 21.034283],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;roun

# %%
punctuality_object1.get_all_busstops()
# Out:
#       Unnamed: 0 zespol  slupek        nazwa_zespolu   szer_geo   dlug_geo  \
# 0              0   1001       1             Kijowska  52.248455  21.044827
# 1              1   1001       2             Kijowska  52.249078  21.044443
# 2              2   1001       3             Kijowska  52.248928  21.044169
# 3              3   1001       4             Kijowska  52.249969  21.041588
# 4              4   1001       5             Kijowska  52.250319  21.043861
# ...          ...    ...     ...                  ...        ...        ...
# 7050        7050   R-11      99       ZEA KLESZCZOWA  52.196605  20.922746
# 7051        7051   R-13       0          ZEA STALOWA  52.263590  21.047868
# 7052        7052   R-13      99          ZEA STALOWA  52.263631  21.047922
# 7053        7053   R-19       0  WYDZIAŁ WŁOŚCIAŃSKA  52.271236  20.968586
# 7054        7054   R-19      99  WYDZIAŁ WŁOŚCIAŃSKA  52.271236  20.968496
#
#       late  all
# 0        0   18
# 1        2    8
# 2        0    0
# 3        0    0
# 4        0    0
# ...    ...  ...
# 7050     0    0
# 7051     0    1
# 7052     0    0
# 7053     0    0
# 7054     0    0
#
# [7055 rows x 8 columns]

# %% [markdown]
# ### After 19:50:

# %%
punctuality_object2 = am.get_punctuality_object("2024-02-20, 19:50 ztm", "2024-02-20 schedule")
#punctuality_object2.count_late_buses(True)
punctuality_object2.load_late_buses("out2.csv")
punctuality_object2.analize_delays(4, 0.5, True, True)
# Out:
# Buses were deleyed in 8.52% measured cases.
# Busstops without any delay: 950
# Number of busstops satisfing function's conditions (at least 4 buses): 1666
# Table with the most deleyed busstops:
#      zespol  slupek         nazwa_zespolu   szer_geo   dlug_geo  late  all  \
# 5234   4348       1   PKP Żwirki i Wigury  52.193570  20.981904     6    8
# 3366   3126       2              Tagore'a  52.195369  21.007382     3    5
# 4100   3701      71                 Zgoda  52.074815  21.029482     3    5
# 3477   3168       1  Kolejka Piaseczyńska  52.069128  21.025004     3    5
# 3700   3255       2            Miłobędzka  52.197028  20.992109     3    5
# 6866   7054       3        Park Traugutta  52.258470  21.002556     3    5
# 6497   6407       2      Łomianki-Centrum  52.339728  20.890891     3    5
#
#       percent
# 5234     0.75
# 3366     0.60
# 4100     0.60
# 3477     0.60
# 3700     0.60
# 6866     0.60
# 6497     0.60
# Map with delays:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9fc0680c653c87a9567369dec4364fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9fc0680c653c87a9567369dec4364fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9fc0680c653c87a9567369dec4364fc = L.map(
#                 &quot;map_c9fc0680c653c87a9567369dec4364fc&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20ad762d94176cffa89d7a8389d65dae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_20ad762d94176cffa89d7a8389d65dae.addTo(map_c9fc0680c653c87a9567369dec4364fc);
#
#
#             var circle_marker_c8f41772b76bd6a6e1a984a466acf6d4 = L.circleMarker(
#                 [52.19357, 20.981904],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c9fc0680c653c87a9567369dec4364fc);
#
#
#         var popup_fa5a21cd07eeb027e3f034bb04ad9de0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c1536d72ba229f748dd623dffd36b43 = $(`&lt;div id=&quot;html_8c1536d72ba229f748dd623dffd36b43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.75&lt;/div&gt;`)[0];
#                 popup_fa5a21cd07eeb027e3f034bb04ad9de0.setContent(html_8c1536d72ba229f748dd623dffd36b43);
#
#
#
#         circle_marker_c8f41772b76bd6a6e1a984a466acf6d4.bindPopup(popup_fa5a21cd07eeb027e3f034bb04ad9de0)
#         ;
#
#
#
#
#             var circle_marker_69c599dab19622e7e0acddfeb65bb536 = L.circleMarker(
#                 [52.195369, 21.007382],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c9fc0680c653c87a9567369dec4364fc);
#
#
#         var popup_4f0c7dbc97127d4183adc73d799a8cde = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a96f7ffb7dd7d25482f77d3edc4ad54 = $(`&lt;div id=&quot;html_8a96f7ffb7dd7d25482f77d3edc4ad54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.6&lt;/div&gt;`)[0];
#                 popup_4f0c7dbc97127d4183adc73d799a8cde.setContent(html_8a96f7ffb7dd7d25482f77d3edc4ad54);
#
#
#
#         circle_marker_69c599dab19622e7e0acddfeb65bb536.bindPopup(popup_4f0c7dbc97127d4183adc73d799a8cde)
#         ;
#
#
#
#
#             var circle_marker_60096816e3efab948795bafeb1b864b1 = L.circleMarker(
#                 [52.074815, 21.029482],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c9fc0680c653c87a9567369dec4364fc);
#
#
#         var popup_a94faa963ae2d6d6a44b70d870178783 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b912d94e6f2f3d16324d1a9b49bde39 = $(`&lt;div id=&quot;html_7b912d94e6f2f3d16324d1a9b49bde39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.6&lt;/div&gt;`)[0];
#                 popup_a94faa963ae2d6d6a44b70d870178783.setContent(html_7b912d94e6f2f3d16324d1a9b49bde39);
#
#
#
#         circle_marker_60096816e3efab948795bafeb1b864b1.bindPopup(popup_a94faa963ae2d6d6a44b70d870178783)
#         ;
#
#
#
#
#             var circle_marker_896e225ed436f8e1eae912db5d698000 = L.circleMarker(
#                 [52.069128, 21.025004],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&
