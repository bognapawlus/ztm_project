# %%
import analysis.analysis_module as am
#!pip install --upgrade /home/bona9/notebook/aaazal

# %%
current_locations = am.get_current_locations_object("2024-02-20, 12:38 ztm")
schedule1 = am.get_schedule_object("2024-02-20 schedule")

# %% [markdown]
# ### Downloading tables:

# %%
current_locations.get_data()
# Out:
#      Lines        Lon VehicleNumber                Time        Lat Brigade
# 0      213  21.102235          1000 2024-02-20 13:14:03  52.222823       3
# 1      213  21.188761          1001 2024-02-20 13:14:00  52.149900       1
# 2      213  21.114889          1002 2024-02-20 10:48:23  52.234758       3
# 3      311  21.077794          1003 2024-02-20 13:14:04  52.243432     503
# 4      213  21.233823          1004 2024-02-20 13:14:04  52.178699       5
# ...    ...        ...           ...                 ...        ...     ...
# 1768   186  20.874670          9951 2024-02-20 01:11:29  52.279209      10
# 1769   193  21.025311          9952 2024-02-20 12:59:25  52.173477       3
# 1770   193  20.875103          9953 2024-02-20 00:14:26  52.279316       3
# 1771   186  20.986816          9954 2024-02-20 12:59:29  52.305592      12
# 1772   114  20.928116          9955 2024-02-20 12:59:17  52.271717       6
#
# [72676 rows x 6 columns]

# %%
schedule1.get_busstops_data()
# Out:
#      zespol slupek        nazwa_zespolu   szer_geo   dlug_geo
# 0      1001     01             Kijowska  52.248455  21.044827
# 1      1001     02             Kijowska  52.249078  21.044443
# 2      1001     03             Kijowska  52.248928  21.044169
# 3      1001     04             Kijowska  52.249969  21.041588
# 4      1001     05             Kijowska  52.250319  21.043861
# ...     ...    ...                  ...        ...        ...
# 7050   R-11     99       ZEA KLESZCZOWA  52.196605  20.922746
# 7051   R-13     00          ZEA STALOWA  52.263590  21.047868
# 7052   R-13     99          ZEA STALOWA  52.263631  21.047922
# 7053   R-19     00  WYDZIAŁ WŁOŚCIAŃSKA  52.271236  20.968586
# 7054   R-19     99  WYDZIAŁ WŁOŚCIAŃSKA  52.271236  20.968496
#
# [7055 rows x 5 columns]

# %%
schedule1.get_lines_from_busstop('1001', '01')
# Out:
#    linia
# 0    102
# 1    123
# 2    125
# 3    138
# 4    146
# 5    147
# 6    166
# 7    202
# 8    509
# 9    N02
# 10   N03
# 11   N21
# 12   N71

# %%
schedule1.get_schedule('1001', '01', '102', 
                       current_locations.get_start_time_of_downloading(), 
                       current_locations.get_end_time_of_downloading())
# Out:
#    brygada                czas
# 26     548 2024-02-20 12:45:00
# 27     545 2024-02-20 13:05:00

# %% [markdown]
# # 1. Buses with speed over 60 - analysis:
#
# ### After 12:38:

# %%
current_locations_bus1 = am.get_current_locations_object("2024-02-20, 12:38 ztm")
ans1_speed = current_locations_bus1.analysis_of_all_buses_speed(60, True)
# Out:
# How many buses exceeded the speed: 51
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59f2fa4e62f45210245eb6a60ec4396f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59f2fa4e62f45210245eb6a60ec4396f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59f2fa4e62f45210245eb6a60ec4396f = L.map(
#                 &quot;map_59f2fa4e62f45210245eb6a60ec4396f&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15278a6ca40972647701e75b776623ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_15278a6ca40972647701e75b776623ff.addTo(map_59f2fa4e62f45210245eb6a60ec4396f);
#
#
#             var marker_9d48fc94de7e914571374886e407c09f = L.marker(
#                 [52.4207622, 21.0594923],
#                 {}
#             ).addTo(map_59f2fa4e62f45210245eb6a60ec4396f);
#
#
#         var popup_1f746f655309285038938976f54e9e8f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a5521c1d972f7d69d1f9e9b1d8591a7 = $(`&lt;div id=&quot;html_8a5521c1d972f7d69d1f9e9b1d8591a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_1f746f655309285038938976f54e9e8f.setContent(html_8a5521c1d972f7d69d1f9e9b1d8591a7);
#
#
#
#         marker_9d48fc94de7e914571374886e407c09f.bindPopup(popup_1f746f655309285038938976f54e9e8f)
#         ;
#
#
#
#
#             var marker_e20c30ee9d7a620e6e8d367c1e648c15 = L.marker(
#                 [52.19125085, 21.0746583],
#                 {}
#             ).addTo(map_59f2fa4e62f45210245eb6a60ec4396f);
#
#
#         var popup_de8c7e99df71ac5168def21ba4f91844 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cd0f91884eab40863b7f907a1e63eb2e = $(`&lt;div id=&quot;html_cd0f91884eab40863b7f907a1e63eb2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_de8c7e99df71ac5168def21ba4f91844.setContent(html_cd0f91884eab40863b7f907a1e63eb2e);
#
#
#
#         marker_e20c30ee9d7a620e6e8d367c1e648c15.bindPopup(popup_de8c7e99df71ac5168def21ba4f91844)
#         ;
#
#
#
#
#             var marker_2ff2695797dee747d5db65f34bbed539 = L.marker(
#                 [52.209305, 21.0853705],
#                 {}
#             ).addTo(map_59f2fa4e62f45210245eb6a60ec4396f);
#
#
#         var popup_6acd039e9c119a8360446608bad5d961 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e794eb56096bed0ca786e214e6325e08 = $(`&lt;div id=&quot;html_e794eb56096bed0ca786e214e6325e08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_6acd039e9c119a8360446608bad5d961.setContent(html_e794eb56096bed0ca786e214e6325e08);
#
#
#
#         marker_2ff2695797dee747d5db65f34bbed539.bindPopup(popup_6acd039e9c119a8360446608bad5d961)
#         ;
#
#
#
#
#             var marker_011143028cf21b2c8693fb49986cf4f6 = L.marker(
#                 [52.17881645, 21.14088885],
#                 {}
#             ).addTo(map_59f2fa4e62f45210245eb6a60ec4396f);
#
#
#         var popup_75a2a3f01773c67f16d3f25c9fdc830c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_31b648e050609906973145393b5278af = $(`&lt;div id=&quot;html_31b648e050609906973145393b5278af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_75a2a3f01773c67f16d3f25c9fdc830c.setContent(html_31b648e050609906973145393b5278af);
#
#
#
#         marker_011143028cf21b2c8693fb49986cf4f6.bindPopup(popup_75a2a3f01773c67f16d3f25c9fdc830c)
#         ;
#
#
#
#
#             var marker_8061561d1fcc5cced2b2ff24bc4cb179 = L.marker(
#                 [52.207095949999996, 21.081533999999998],
#                 {}
#             ).addTo(map_59f2fa4e62f45210245eb6a60ec4396f);
#
#
#         var popup_61a4a712f3009041bd61fe3fdf4cced6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_52bf4795f9f3f2bf546fead857b7d6f2 = $(`&lt;div id=&quot;html_52bf4795f9f3f2bf546fead857b7d6f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_61a4a712f3009041bd61fe3fdf4cced6.setContent(html_52bf4795f9f3f2bf546fead857b7d6f2);
#
#
#
#         marker_8061561d1fcc5cced2b2ff24bc4cb179.bindPopup(popup_61a4a712f3009041bd61fe3fdf4cced6)
#         ;
#
#
#
#
#             var marker_5e5bf9c645601ed7696a21b5a2ba3f86 = L.marker(
#                 [52.2025735, 21.115009999999998],
#                 {}
#             ).addTo(map_59f2fa4e62f45210245eb6a60ec4396f);

# %% [markdown]
# ### After 19:50:

# %%
current_locations_bus2 = am.get_current_locations_object("2024-02-20, 19:50 ztm")
ans2_speed = current_locations_bus2.analysis_of_all_buses_speed(60, True)
# Out:
# How many buses exceeded the speed: 89
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c23988064c18de7db26f5be8539dcf1f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c23988064c18de7db26f5be8539dcf1f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c23988064c18de7db26f5be8539dcf1f = L.map(
#                 &quot;map_c23988064c18de7db26f5be8539dcf1f&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d077e290b3c367a15d99a30afb666dfe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d077e290b3c367a15d99a30afb666dfe.addTo(map_c23988064c18de7db26f5be8539dcf1f);
#
#
#             var marker_8d4ce5a23c20238de3f115a4ff1755b1 = L.marker(
#                 [52.168828500000004, 21.0135045],
#                 {}
#             ).addTo(map_c23988064c18de7db26f5be8539dcf1f);
#
#
#         var popup_170e2fab8697590d0be5ace5e3bf4056 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_941055c90fb956d1207d6ed8fb1cc085 = $(`&lt;div id=&quot;html_941055c90fb956d1207d6ed8fb1cc085&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_170e2fab8697590d0be5ace5e3bf4056.setContent(html_941055c90fb956d1207d6ed8fb1cc085);
#
#
#
#         marker_8d4ce5a23c20238de3f115a4ff1755b1.bindPopup(popup_170e2fab8697590d0be5ace5e3bf4056)
#         ;
#
#
#
#
#             var marker_610e7d107f4df960924dce1b60a41131 = L.marker(
#                 [52.1618045, 21.0176595],
#                 {}
#             ).addTo(map_c23988064c18de7db26f5be8539dcf1f);
#
#
#         var popup_d7fd417d3005cc906177bb8bd49fb294 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4d992543c2fb6c830770274108f936a5 = $(`&lt;div id=&quot;html_4d992543c2fb6c830770274108f936a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_d7fd417d3005cc906177bb8bd49fb294.setContent(html_4d992543c2fb6c830770274108f936a5);
#
#
#
#         marker_610e7d107f4df960924dce1b60a41131.bindPopup(popup_d7fd417d3005cc906177bb8bd49fb294)
#         ;
#
#
#
#
#             var marker_09bcb9e0fadbc47d862cdb497a8836bf = L.marker(
#                 [52.206939500000004, 21.07959],
#                 {}
#             ).addTo(map_c23988064c18de7db26f5be8539dcf1f);
#
#
#         var popup_b6042d6b5dfaf9e00656ebfd1bc2d890 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3b73ae9c96876e1886c1aba96e626864 = $(`&lt;div id=&quot;html_3b73ae9c96876e1886c1aba96e626864&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_b6042d6b5dfaf9e00656ebfd1bc2d890.setContent(html_3b73ae9c96876e1886c1aba96e626864);
#
#
#
#         marker_09bcb9e0fadbc47d862cdb497a8836bf.bindPopup(popup_b6042d6b5dfaf9e00656ebfd1bc2d890)
#         ;
#
#
#
#
#             var marker_e6078477fdc8b3fd07765e744738f96b = L.marker(
#                 [52.2145765, 21.092980500000003],
#                 {}
#             ).addTo(map_c23988064c18de7db26f5be8539dcf1f);
#
#
#         var popup_df3cd3c61aadf508ea5db04d6b8ea105 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f96faf33ebbe0865919314b7460ec88d = $(`&lt;div id=&quot;html_f96faf33ebbe0865919314b7460ec88d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_df3cd3c61aadf508ea5db04d6b8ea105.setContent(html_f96faf33ebbe0865919314b7460ec88d);
#
#
#
#         marker_e6078477fdc8b3fd07765e744738f96b.bindPopup(popup_df3cd3c61aadf508ea5db04d6b8ea105)
#         ;
#
#
#
#
#             var marker_77e80ae81f48f8f429145faaae566b0a = L.marker(
#                 [52.2136515, 21.092122],
#                 {}
#             ).addTo(map_c23988064c18de7db26f5be8539dcf1f);
#
#
#         var popup_0df6014eeda8ec8d055c5a74c4dacdc1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cfc7bc83fc85c7181b1ef027e4c25be7 = $(`&lt;div id=&quot;html_cfc7bc83fc85c7181b1ef027e4c25be7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_0df6014eeda8ec8d055c5a74c4dacdc1.setContent(html_cfc7bc83fc85c7181b1ef027e4c25be7);
#
#
#
#         marker_77e80ae81f48f8f429145faaae566b0a.bindPopup(popup_0df6014eeda8ec8d055c5a74c4dacdc1)
#         ;
#
#
#
#
#             var marker_ecfabd2675ac310706d30b9290c5bd5b = L.marker(
#                 [52.25041485, 21.14812565],
#                 {}
#             ).addTo(map_c23988064c18de7db26f5be8539dcf1f);

# %% [markdown]
# # Places with a lot of high speeds
# ### After 12:38:

# %%
current_locations_bus1.get_locations_with_lots_overspeeds()
# Out:
# There were 7 areas where at least 3 buses exceded the speed limit.
# Map with these places with aproximate high-speed-steets and with informations
#         how many high-speed measurements where in this area:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d980fd79d4481f179bc1fefdc577e846 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d980fd79d4481f179bc1fefdc577e846&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d980fd79d4481f179bc1fefdc577e846 = L.map(
#                 &quot;map_d980fd79d4481f179bc1fefdc577e846&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9884621d6edbdc63eb597875851cf00b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9884621d6edbdc63eb597875851cf00b.addTo(map_d980fd79d4481f179bc1fefdc577e846);
#
#
#             var poly_line_b61a1ea5412a433774b5a76b919fa26d = L.polyline(
#                 [[52.2964164, 20.93439845], [52.29927835, 20.93816005]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d980fd79d4481f179bc1fefdc577e846);
#
#
#             var poly_line_c2c7c2635b1523182753f04918413c59 = L.polyline(
#                 [[52.29927835, 20.93816005], [52.29907675, 20.9385238]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d980fd79d4481f179bc1fefdc577e846);
#
#
#             var poly_line_b312b3d7409d38cd85008528173ebb03 = L.polyline(
#                 [[52.29907675, 20.9385238], [52.30068795, 20.9416023]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d980fd79d4481f179bc1fefdc577e846);
#
#
#             var poly_line_9ed51cc0bfc5eef68fcb289b1531f48e = L.polyline(
#                 [[52.30068795, 20.9416023], [52.30211655, 20.9422728]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d980fd79d4481f179bc1fefdc577e846);
#
#
#             var poly_line_58b983ddfe00dc45da981bc7495bcd78 = L.polyline(
#                 [[52.30211655, 20.9422728], [52.30403445, 20.9457737]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d980fd79d4481f179bc1fefdc577e846);
#
#
#             var poly_line_0cb322378411ed346546ae45b0a39280 = L.polyline(
#                 [[52.30403445, 20.9457737], [52.306010150000006, 20.950071649999998]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&q

# %% [markdown]
# ### After 19:50:

# %%
current_locations_bus2.get_locations_with_lots_overspeeds()
# Out:
# There were 13 areas where at least 3 buses exceded the speed limit.
# Map with these places with aproximate high-speed-steets and with informations
#         how many high-speed measurements where in this area:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13a1093b5ab0eb36a24971771d415b93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13a1093b5ab0eb36a24971771d415b93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13a1093b5ab0eb36a24971771d415b93 = L.map(
#                 &quot;map_13a1093b5ab0eb36a24971771d415b93&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ff362cb6191c4ea292a07f8f7a742b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3ff362cb6191c4ea292a07f8f7a742b9.addTo(map_13a1093b5ab0eb36a24971771d415b93);
#
#
#             var poly_line_9a1fe41ef8890b9317fa9163139db61f = L.polyline(
#                 [[52.1687508335, 21.012320666999997], [52.168828500000004, 21.0135045]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_13a1093b5ab0eb36a24971771d415b93);
#
#
#             var poly_line_3a397573218c0a06f4bbacc53de7d2a7 = L.polyline(
#                 [[52.168828500000004, 21.0135045], [52.1679015, 21.016933]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_13a1093b5ab0eb36a24971771d415b93);
#
#
#             var poly_line_c5e4f8df3f06232356836e59cbe24f7f = L.polyline(
#                 [[52.1679015, 21.016933], [52.1618045, 21.0176595]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_13a1093b5ab0eb36a24971771d415b93);
#
#
#             var poly_line_e38a30d69cccebbec2b16df6bcf366e4 = L.polyline(
#                 [[52.1618045, 21.0176595], [52.1605639, 21.01768975]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_13a1093b5ab0eb36a24971771d415b93);
#
#
#             var poly_line_1427544ebe94ec1480b632dcd5bc81ff = L.polyline(
#                 [[52.1605639, 21.01768975], [52.1589072, 21.0176915]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_13a1093b5ab0eb36a24971771d415b93);
#
#
#             var poly_line_46b6692f15db761ffe71959c8032123e = L.polyline(
#                 [[52.1589072, 21.0176915], [52.166767667, 21.02533425]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&

# %% [markdown]
# # Punctuality:
# ### After 12:38:

# %%
punctuality_object1 = am.get_punctuality_object("2024-02-20, 12:38 ztm", "2024-02-20 schedule")
#punctuality_object1.count_late_buses(True)
punctuality_object1.load_late_buses("out1.csv")
punctuality_object1.analize_delays(4, 0.2, True, True)
# Out:
# Buses were deleyed in 11.58% measured cases.
# Busstops without any delay: 824
# Number of busstops satisfing function's conditions (at least 4 buses): 1532
# Table with the most deleyed busstops:
#      zespol  slupek               nazwa_zespolu   szer_geo   dlug_geo  late  \
# 4676   4038       1  Komitetu Obrony Robotników  52.178995  20.978165     5
# 4789   4085       2                    Radarowa  52.188762  20.962959     7
# 4675   4037       4                     Sasanki  52.184058  20.977725     7
# 3092   3027      52                       Dolna  52.202896  21.034283    11
# 4595   4011       6                       Hynka  52.190608  20.957315     5
# 5003   4200       1     Lotnisko Chopina-Odloty  52.172074  20.973369     5
# 4793   4087       2                   Orzechowa  52.192147  20.949007     4
#
#       all   percent
# 4676    5  1.000000
# 4789    7  1.000000
# 4675    8  0.875000
# 3092   13  0.846154
# 4595    6  0.833333
# 5003    6  0.833333
# 4793    5  0.800000
# Map with delays:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47e99f66d84534f78ea2d47b1415cc49 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47e99f66d84534f78ea2d47b1415cc49&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47e99f66d84534f78ea2d47b1415cc49 = L.map(
#                 &quot;map_47e99f66d84534f78ea2d47b1415cc49&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d63c3216a7e712b87d2a0b2be611daa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9d63c3216a7e712b87d2a0b2be611daa.addTo(map_47e99f66d84534f78ea2d47b1415cc49);
#
#
#             var circle_marker_bd44ab290be48051590628a938f24097 = L.circleMarker(
#                 [52.178995, 20.978165],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ba4a00&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_47e99f66d84534f78ea2d47b1415cc49);
#
#
#         var popup_d07f0360337cfd82eb98b84d7fd1076b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_74843b7ea459fcc1236875ed7867065a = $(`&lt;div id=&quot;html_74843b7ea459fcc1236875ed7867065a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1.0&lt;/div&gt;`)[0];
#                 popup_d07f0360337cfd82eb98b84d7fd1076b.setContent(html_74843b7ea459fcc1236875ed7867065a);
#
#
#
#         circle_marker_bd44ab290be48051590628a938f24097.bindPopup(popup_d07f0360337cfd82eb98b84d7fd1076b)
#         ;
#
#
#
#
#             var circle_marker_fbc9472e50f0b07294e8211836e5f236 = L.circleMarker(
#                 [52.188762, 20.962959],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ba4a00&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_47e99f66d84534f78ea2d47b1415cc49);
#
#
#         var popup_86e7efdbc32a1ac2b482780533c6fdae = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a3ceabc271559e7166a2c704d2f07b07 = $(`&lt;div id=&quot;html_a3ceabc271559e7166a2c704d2f07b07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1.0&lt;/div&gt;`)[0];
#                 popup_86e7efdbc32a1ac2b482780533c6fdae.setContent(html_a3ceabc271559e7166a2c704d2f07b07);
#
#
#
#         circle_marker_fbc9472e50f0b07294e8211836e5f236.bindPopup(popup_86e7efdbc32a1ac2b482780533c6fdae)
#         ;
#
#
#
#
#             var circle_marker_5a1d234d984845aacd87abb198c7598e = L.circleMarker(
#                 [52.184058, 20.977725],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_47e99f66d84534f78ea2d47b1415cc49);
#
#
#         var popup_99972c86fc4e6134224c90245ba1cb61 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5575f378bbe84addf715f03f305c89e4 = $(`&lt;div id=&quot;html_5575f378bbe84addf715f03f305c89e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.875&lt;/div&gt;`)[0];
#                 popup_99972c86fc4e6134224c90245ba1cb61.setContent(html_5575f378bbe84addf715f03f305c89e4);
#
#
#
#         circle_marker_5a1d234d984845aacd87abb198c7598e.bindPopup(popup_99972c86fc4e6134224c90245ba1cb61)
#         ;
#
#
#
#
#             var circle_marker_68ae3b977518658a844790e5cce32f7d = L.circleMarker(
#                 [52.202896, 21.034283],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;roun

# %%
punctuality_object1.get_all_busstops()
# Out:
#       Unnamed: 0 zespol  slupek        nazwa_zespolu   szer_geo   dlug_geo  \
# 0              0   1001       1             Kijowska  52.248455  21.044827
# 1              1   1001       2             Kijowska  52.249078  21.044443
# 2              2   1001       3             Kijowska  52.248928  21.044169
# 3              3   1001       4             Kijowska  52.249969  21.041588
# 4              4   1001       5             Kijowska  52.250319  21.043861
# ...          ...    ...     ...                  ...        ...        ...
# 7050        7050   R-11      99       ZEA KLESZCZOWA  52.196605  20.922746
# 7051        7051   R-13       0          ZEA STALOWA  52.263590  21.047868
# 7052        7052   R-13      99          ZEA STALOWA  52.263631  21.047922
# 7053        7053   R-19       0  WYDZIAŁ WŁOŚCIAŃSKA  52.271236  20.968586
# 7054        7054   R-19      99  WYDZIAŁ WŁOŚCIAŃSKA  52.271236  20.968496
#
#       late  all
# 0        0   18
# 1        2    8
# 2        0    0
# 3        0    0
# 4        0    0
# ...    ...  ...
# 7050     0    0
# 7051     0    1
# 7052     0    0
# 7053     0    0
# 7054     0    0
#
# [7055 rows x 8 columns]

# %% [markdown]
# ### After 19:50:

# %%
punctuality_object2 = am.get_punctuality_object("2024-02-20, 19:50 ztm", "2024-02-20 schedule")
#punctuality_object2.count_late_buses(True)
punctuality_object2.load_late_buses("out2.csv")
punctuality_object2.analize_delays(4, 0.2, True, True)
# Out:
# Buses were deleyed in 8.52% measured cases.
# Busstops without any delay: 950
# Number of busstops satisfing function's conditions (at least 4 buses): 1666
# Table with the most deleyed busstops:
#      zespol  slupek         nazwa_zespolu   szer_geo   dlug_geo  late  all  \
# 5234   4348       1   PKP Żwirki i Wigury  52.193570  20.981904     6    8
# 3366   3126       2              Tagore'a  52.195369  21.007382     3    5
# 4100   3701      71                 Zgoda  52.074815  21.029482     3    5
# 3477   3168       1  Kolejka Piaseczyńska  52.069128  21.025004     3    5
# 3700   3255       2            Miłobędzka  52.197028  20.992109     3    5
# 6866   7054       3        Park Traugutta  52.258470  21.002556     3    5
# 6497   6407       2      Łomianki-Centrum  52.339728  20.890891     3    5
#
#       percent
# 5234     0.75
# 3366     0.60
# 4100     0.60
# 3477     0.60
# 3700     0.60
# 6866     0.60
# 6497     0.60
# Map with delays:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc85bb09433f2817fb94f7a39d38b809 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc85bb09433f2817fb94f7a39d38b809&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc85bb09433f2817fb94f7a39d38b809 = L.map(
#                 &quot;map_bc85bb09433f2817fb94f7a39d38b809&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_306f04ef0f450d1da2587c8116a484df = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_306f04ef0f450d1da2587c8116a484df.addTo(map_bc85bb09433f2817fb94f7a39d38b809);
#
#
#             var circle_marker_708a1fdfb1d2fcf3285cbb0550fb961e = L.circleMarker(
#                 [52.19357, 20.981904],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bc85bb09433f2817fb94f7a39d38b809);
#
#
#         var popup_00eaf72edf6a3e3f17ad9f263583a3ca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_336fa7fad535e37f72af3559538d2b7e = $(`&lt;div id=&quot;html_336fa7fad535e37f72af3559538d2b7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.75&lt;/div&gt;`)[0];
#                 popup_00eaf72edf6a3e3f17ad9f263583a3ca.setContent(html_336fa7fad535e37f72af3559538d2b7e);
#
#
#
#         circle_marker_708a1fdfb1d2fcf3285cbb0550fb961e.bindPopup(popup_00eaf72edf6a3e3f17ad9f263583a3ca)
#         ;
#
#
#
#
#             var circle_marker_99da35c4bcfd6180a3ea410e14e4fb85 = L.circleMarker(
#                 [52.195369, 21.007382],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bc85bb09433f2817fb94f7a39d38b809);
#
#
#         var popup_57124dff167bf335675646a45f0d48d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d601e38974fec1fae3e0e210d8c6c7cd = $(`&lt;div id=&quot;html_d601e38974fec1fae3e0e210d8c6c7cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.6&lt;/div&gt;`)[0];
#                 popup_57124dff167bf335675646a45f0d48d8.setContent(html_d601e38974fec1fae3e0e210d8c6c7cd);
#
#
#
#         circle_marker_99da35c4bcfd6180a3ea410e14e4fb85.bindPopup(popup_57124dff167bf335675646a45f0d48d8)
#         ;
#
#
#
#
#             var circle_marker_e651034c09a46773a560e88b5128204c = L.circleMarker(
#                 [52.074815, 21.029482],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bc85bb09433f2817fb94f7a39d38b809);
#
#
#         var popup_d80e88312ef63473c6849173587f5629 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f3ddf9f85090c9381e92cd2acb54d73 = $(`&lt;div id=&quot;html_6f3ddf9f85090c9381e92cd2acb54d73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.6&lt;/div&gt;`)[0];
#                 popup_d80e88312ef63473c6849173587f5629.setContent(html_6f3ddf9f85090c9381e92cd2acb54d73);
#
#
#
#         circle_marker_e651034c09a46773a560e88b5128204c.bindPopup(popup_d80e88312ef63473c6849173587f5629)
#         ;
#
#
#
#
#             var circle_marker_5ca789807ad5da8707ef0b4014a1373c = L.circleMarker(
#                 [52.069128, 21.025004],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&

# %% [markdown]
# ## Which busstops have less delays at after 12:38 than after 19:50 - analysis

# %%
punctuality_object1.get_better_busstops(punctuality_object2)
# Out:
# For "2024-02-20, 12:38 ztm" there are 337 busstops with better delay rate
# than for "2024-02-20, 19:50 ztm"
#
# Table with the best difference busstops:
#       slupek           nazwa_zespolu      diff
# 3150       2                   Vogla  0.500000
# 4845       2           Sosnkowskiego  0.500000
# 5337       1  Połczyńska-parking P+R  0.444444
# 4817       2             Wapowskiego  0.400000
# 6497       2        Łomianki-Centrum  0.400000
# 5867       1                Lazurowa  0.375000
# 2605       3                 Torfowa  0.375000
# The map shows busstops with smaller number of delays for our object
# green point - small difference in delay rate
# red point - big difference
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d39c6ae435baa64f7d83392c191a12f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d39c6ae435baa64f7d83392c191a12f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d39c6ae435baa64f7d83392c191a12f = L.map(
#                 &quot;map_4d39c6ae435baa64f7d83392c191a12f&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c56ebd167d062e2ac51dd25d6c09915 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2c56ebd167d062e2ac51dd25d6c09915.addTo(map_4d39c6ae435baa64f7d83392c191a12f);
#
#
#             var circle_marker_41f1690b057dfd06f5dae7573ad3c7d5 = L.circleMarker(
#                 [52.160352, 21.086672],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f39c12&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4d39c6ae435baa64f7d83392c191a12f);
#
#
#         var popup_c1eeaa253e72d02542d5631d3ffab1df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_05531e90c39678d704f288fd00c2b6d4 = $(`&lt;div id=&quot;html_05531e90c39678d704f288fd00c2b6d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.5&lt;/div&gt;`)[0];
#                 popup_c1eeaa253e72d02542d5631d3ffab1df.setContent(html_05531e90c39678d704f288fd00c2b6d4);
#
#
#
#         circle_marker_41f1690b057dfd06f5dae7573ad3c7d5.bindPopup(popup_c1eeaa253e72d02542d5631d3ffab1df)
#         ;
#
#
#
#
#             var circle_marker_b9b0dd1e57601f22735b8f504c0fa135 = L.circleMarker(
#                 [52.189665, 20.88677],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f39c12&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4d39c6ae435baa64f7d83392c191a12f);
#
#
#         var popup_6c51d365f7f603820ae253c7b42a6421 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63ce846ba1b81db5859867b436e12cd2 = $(`&lt;div id=&quot;html_63ce846ba1b81db5859867b436e12cd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.5&lt;/div&gt;`)[0];
#                 popup_6c51d365f7f603820ae253c7b42a6421.setContent(html_63ce846ba1b81db5859867b436e12cd2);
#
#
#
#         circle_marker_b9b0dd1e57601f22735b8f504c0fa135.bindPopup(popup_6c51d365f7f603820ae253c7b42a6421)
#         ;
#
#
#
#
#             var circle_marker_59082aa75a1d504c78edb5a9f688ba77 = L.circleMarker(
#                 [52.221784, 20.923929],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f1c40f&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_4d39c6ae435baa64f7d83392c191a12f);
#
#
#         var popup_92c092bcaf99c5ef02e3a1c70bcd01b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_88ead9fc92771d5b5c04ef7d9b941a8d = $(`&lt;div id=&quot;html_88ead9fc92771d5b5c04ef7d9b941a8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.4444444444444444&lt;/div&gt;`)[0];
#                 popup_92c092bcaf99c5ef02e3a1c70bcd01b1.setContent(html_88ead9fc92771d5b5c04ef7d9b941a8d);
#
#
#
#         circle_marker_59082aa75a1d504c78edb5a9f688ba77.bindPopup(popup_92c092bcaf99c5ef02e3a1c70bcd01b1)
#         ;
#
#
#
#
#             var circle_marker_f67f32cb5a71385a6b077433bd3752af = L.circleMarker(
#                 [52.190677, 20.892005],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f1c40f&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;

# %%
punctuality_object2.get_better_busstops(punctuality_object1)
# Out:
# For "2024-02-20, 19:50 ztm" there are 511 busstops with better delay rate
# than for "2024-02-20, 12:38 ztm"
#
# Table with the best difference busstops:
#       slupek               nazwa_zespolu      diff
# 4595       6                       Hynka  0.833333
# 4676       1  Komitetu Obrony Robotników  0.800000
# 4793       2                   Orzechowa  0.800000
# 5003       1     Lotnisko Chopina-Odloty  0.722222
# 3402       1             Miklaszewskiego  0.666667
# 3985       1             Warchałowskiego  0.666667
# 3343       1                Ursynów Płn.  0.666667
# The map shows busstops with smaller number of delays for our object
# green point - small difference in delay rate
# red point - big difference
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b610221209c01e95e8cd85c3b2c9684c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b610221209c01e95e8cd85c3b2c9684c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b610221209c01e95e8cd85c3b2c9684c = L.map(
#                 &quot;map_b610221209c01e95e8cd85c3b2c9684c&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49c553619a9696e2fc9ade350a072d7f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_49c553619a9696e2fc9ade350a072d7f.addTo(map_b610221209c01e95e8cd85c3b2c9684c);
#
#
#             var circle_marker_de386753d8b8b89b68d48728f997f3c7 = L.circleMarker(
#                 [52.190608, 20.957315],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b610221209c01e95e8cd85c3b2c9684c);
#
#
#         var popup_0f1afc549a4a2391fc05dc418efef401 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_be5d7fedbecce27f32ef0e99e93e70b8 = $(`&lt;div id=&quot;html_be5d7fedbecce27f32ef0e99e93e70b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.8333333333333334&lt;/div&gt;`)[0];
#                 popup_0f1afc549a4a2391fc05dc418efef401.setContent(html_be5d7fedbecce27f32ef0e99e93e70b8);
#
#
#
#         circle_marker_de386753d8b8b89b68d48728f997f3c7.bindPopup(popup_0f1afc549a4a2391fc05dc418efef401)
#         ;
#
#
#
#
#             var circle_marker_a108056322f4afed06d76df5ba19c67a = L.circleMarker(
#                 [52.178995, 20.978165],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b610221209c01e95e8cd85c3b2c9684c);
#
#
#         var popup_944c734b5eb7cec1de52db3512c5132c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3fdf6bd4537629a4609d9d9f07f33b78 = $(`&lt;div id=&quot;html_3fdf6bd4537629a4609d9d9f07f33b78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.8&lt;/div&gt;`)[0];
#                 popup_944c734b5eb7cec1de52db3512c5132c.setContent(html_3fdf6bd4537629a4609d9d9f07f33b78);
#
#
#
#         circle_marker_a108056322f4afed06d76df5ba19c67a.bindPopup(popup_944c734b5eb7cec1de52db3512c5132c)
#         ;
#
#
#
#
#             var circle_marker_9a4fbd2a69919059eadf5f52229ab46a = L.circleMarker(
#                 [52.192147, 20.949007],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b610221209c01e95e8cd85c3b2c9684c);
#
#
#         var popup_9d618285b3e319f7769a314f566dd16f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f5e8fd5e2a9495ea9391e166b247ba90 = $(`&lt;div id=&quot;html_f5e8fd5e2a9495ea9391e166b247ba90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.8&lt;/div&gt;`)[0];
#                 popup_9d618285b3e319f7769a314f566dd16f.setContent(html_f5e8fd5e2a9495ea9391e166b247ba90);
#
#
#
#         circle_marker_9a4fbd2a69919059eadf5f52229ab46a.bindPopup(popup_9d618285b3e319f7769a314f566dd16f)
#         ;
#
#
#
#
#             var circle_marker_f253528e79a52edc5a97e951161a687f = L.circleMarker(
#                 [52.172074, 20.973369],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot
