# %%
import analysis.analysis_module as am
#!pip install --upgrade /home/bona9/notebook/aaazal

# %%
current_locations = am.get_current_locations_object("2024-02-20, 12:38 ztm")

schedule1 = am.get_schedule_object("2024-02-20 schedule")

# %% [markdown]
# ### Downloading tables:

# %%
current_locations.get_data()
# Out:
#      Lines        Lon VehicleNumber                Time        Lat Brigade
# 0      213  21.102235          1000 2024-02-20 13:14:03  52.222823       3
# 1      213  21.188761          1001 2024-02-20 13:14:00  52.149900       1
# 2      213  21.114889          1002 2024-02-20 10:48:23  52.234758       3
# 3      311  21.077794          1003 2024-02-20 13:14:04  52.243432     503
# 4      213  21.233823          1004 2024-02-20 13:14:04  52.178699       5
# ...    ...        ...           ...                 ...        ...     ...
# 1768   186  20.874670          9951 2024-02-20 01:11:29  52.279209      10
# 1769   193  21.025311          9952 2024-02-20 12:59:25  52.173477       3
# 1770   193  20.875103          9953 2024-02-20 00:14:26  52.279316       3
# 1771   186  20.986816          9954 2024-02-20 12:59:29  52.305592      12
# 1772   114  20.928116          9955 2024-02-20 12:59:17  52.271717       6
#
# [72676 rows x 6 columns]

# %%
schedule1.get_busstops_data()
# Out:
#      zespol slupek        nazwa_zespolu   szer_geo   dlug_geo
# 0      1001     01             Kijowska  52.248455  21.044827
# 1      1001     02             Kijowska  52.249078  21.044443
# 2      1001     03             Kijowska  52.248928  21.044169
# 3      1001     04             Kijowska  52.249969  21.041588
# 4      1001     05             Kijowska  52.250319  21.043861
# ...     ...    ...                  ...        ...        ...
# 7050   R-11     99       ZEA KLESZCZOWA  52.196605  20.922746
# 7051   R-13     00          ZEA STALOWA  52.263590  21.047868
# 7052   R-13     99          ZEA STALOWA  52.263631  21.047922
# 7053   R-19     00  WYDZIAŁ WŁOŚCIAŃSKA  52.271236  20.968586
# 7054   R-19     99  WYDZIAŁ WŁOŚCIAŃSKA  52.271236  20.968496
#
# [7055 rows x 5 columns]

# %%
schedule1.get_lines_from_busstop('1001', '01')
# Out:
#    linia
# 0    102
# 1    123
# 2    125
# 3    138
# 4    146
# 5    147
# 6    166
# 7    202
# 8    509
# 9    N02
# 10   N03
# 11   N21
# 12   N71

# %%
schedule1.get_schedule('1001', '01', '102', 
                       current_locations.get_start_time_of_downloading(), 
                       current_locations.get_end_time_of_downloading())
# Out:
#    brygada                czas
# 26     548 2024-02-20 12:45:00
# 27     545 2024-02-20 13:05:00

# %% [markdown]
# # 1. Buses with speed over 60 - analysis:
#
# ### After 12:38:

# %%
current_locations_bus1 = am.get_current_locations_object("2024-02-20, 12:38 ztm")
ans1_speed = current_locations_bus1.analysis_of_all_buses_speed(60, True)
# Out:
# How many buses exceeded the speed: 51
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_120bc3c33d3af3579698f8180a61bc49 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_120bc3c33d3af3579698f8180a61bc49&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_120bc3c33d3af3579698f8180a61bc49 = L.map(
#                 &quot;map_120bc3c33d3af3579698f8180a61bc49&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e10c628c925e170f4341a21dd1e0191 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8e10c628c925e170f4341a21dd1e0191.addTo(map_120bc3c33d3af3579698f8180a61bc49);
#
#
#             var marker_09daadc740c0b96bc7b2f0f993b74d39 = L.marker(
#                 [52.4207622, 21.0594923],
#                 {}
#             ).addTo(map_120bc3c33d3af3579698f8180a61bc49);
#
#
#         var popup_25c92de65a60b3c02a01110ce9587f03 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50296458a3a33f82af72221c60977b71 = $(`&lt;div id=&quot;html_50296458a3a33f82af72221c60977b71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_25c92de65a60b3c02a01110ce9587f03.setContent(html_50296458a3a33f82af72221c60977b71);
#
#
#
#         marker_09daadc740c0b96bc7b2f0f993b74d39.bindPopup(popup_25c92de65a60b3c02a01110ce9587f03)
#         ;
#
#
#
#
#             var marker_3f32267685d2280bc7b84453b9d837b6 = L.marker(
#                 [52.19125085, 21.0746583],
#                 {}
#             ).addTo(map_120bc3c33d3af3579698f8180a61bc49);
#
#
#         var popup_1223403dda0f8ae16c2907c58e7a12f9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b1c134f9becd422be42ee752a9419a4d = $(`&lt;div id=&quot;html_b1c134f9becd422be42ee752a9419a4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_1223403dda0f8ae16c2907c58e7a12f9.setContent(html_b1c134f9becd422be42ee752a9419a4d);
#
#
#
#         marker_3f32267685d2280bc7b84453b9d837b6.bindPopup(popup_1223403dda0f8ae16c2907c58e7a12f9)
#         ;
#
#
#
#
#             var marker_2f9185d086f532f259969c83245fbf57 = L.marker(
#                 [52.209305, 21.0853705],
#                 {}
#             ).addTo(map_120bc3c33d3af3579698f8180a61bc49);
#
#
#         var popup_0d55341081a9a62d5f8e64ec9e862731 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8bd5156bb44910d4527893cba53805b4 = $(`&lt;div id=&quot;html_8bd5156bb44910d4527893cba53805b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_0d55341081a9a62d5f8e64ec9e862731.setContent(html_8bd5156bb44910d4527893cba53805b4);
#
#
#
#         marker_2f9185d086f532f259969c83245fbf57.bindPopup(popup_0d55341081a9a62d5f8e64ec9e862731)
#         ;
#
#
#
#
#             var marker_aed755f3b000de4795cb337ecb81c60e = L.marker(
#                 [52.17881645, 21.14088885],
#                 {}
#             ).addTo(map_120bc3c33d3af3579698f8180a61bc49);
#
#
#         var popup_b59f35737eedb7f3130f1adc928594fc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_813a8e07c3c45e941bac9c063fafa7d8 = $(`&lt;div id=&quot;html_813a8e07c3c45e941bac9c063fafa7d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_b59f35737eedb7f3130f1adc928594fc.setContent(html_813a8e07c3c45e941bac9c063fafa7d8);
#
#
#
#         marker_aed755f3b000de4795cb337ecb81c60e.bindPopup(popup_b59f35737eedb7f3130f1adc928594fc)
#         ;
#
#
#
#
#             var marker_813ccb468a3344195c83dfc298748caa = L.marker(
#                 [52.207095949999996, 21.081533999999998],
#                 {}
#             ).addTo(map_120bc3c33d3af3579698f8180a61bc49);
#
#
#         var popup_b1207f7d9eb5c169b1a3f91d640fc136 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_181f269a678d821336c6ba075cf7fa05 = $(`&lt;div id=&quot;html_181f269a678d821336c6ba075cf7fa05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_b1207f7d9eb5c169b1a3f91d640fc136.setContent(html_181f269a678d821336c6ba075cf7fa05);
#
#
#
#         marker_813ccb468a3344195c83dfc298748caa.bindPopup(popup_b1207f7d9eb5c169b1a3f91d640fc136)
#         ;
#
#
#
#
#             var marker_cc7e9f44faf7967f202880a7bb54eb87 = L.marker(
#                 [52.2025735, 21.115009999999998],
#                 {}
#             ).addTo(map_120bc3c33d3af3579698f8180a61bc49);

# %% [markdown]
# ### After 19:50:

# %%
current_locations_bus2 = am.get_current_locations_object("2024-02-20, 19:50 ztm")
ans2_speed = current_locations_bus2.analysis_of_all_buses_speed(60, True)
# Out:
# How many buses exceeded the speed: 89
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6de3df385e60494bb42da5520c978a4e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6de3df385e60494bb42da5520c978a4e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6de3df385e60494bb42da5520c978a4e = L.map(
#                 &quot;map_6de3df385e60494bb42da5520c978a4e&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1517b287f0ffb79e2894c56948728915 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1517b287f0ffb79e2894c56948728915.addTo(map_6de3df385e60494bb42da5520c978a4e);
#
#
#             var marker_dc9b47ed4e3c8765e85cd11ba356b92b = L.marker(
#                 [52.168828500000004, 21.0135045],
#                 {}
#             ).addTo(map_6de3df385e60494bb42da5520c978a4e);
#
#
#         var popup_fa33643f3c3396d6197a8a3d98fc6d08 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a541506d2f595b97affbd9bd47771f53 = $(`&lt;div id=&quot;html_a541506d2f595b97affbd9bd47771f53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_fa33643f3c3396d6197a8a3d98fc6d08.setContent(html_a541506d2f595b97affbd9bd47771f53);
#
#
#
#         marker_dc9b47ed4e3c8765e85cd11ba356b92b.bindPopup(popup_fa33643f3c3396d6197a8a3d98fc6d08)
#         ;
#
#
#
#
#             var marker_f2b44c6997285308dec46e0ce4211e13 = L.marker(
#                 [52.1618045, 21.0176595],
#                 {}
#             ).addTo(map_6de3df385e60494bb42da5520c978a4e);
#
#
#         var popup_3bc189682f22d9754b3a4adc2c4a71d3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c1b6b75d7b6d3268349532fc1b6ac3be = $(`&lt;div id=&quot;html_c1b6b75d7b6d3268349532fc1b6ac3be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_3bc189682f22d9754b3a4adc2c4a71d3.setContent(html_c1b6b75d7b6d3268349532fc1b6ac3be);
#
#
#
#         marker_f2b44c6997285308dec46e0ce4211e13.bindPopup(popup_3bc189682f22d9754b3a4adc2c4a71d3)
#         ;
#
#
#
#
#             var marker_9b8f5a82336ac7cae99c05dc0fd4c701 = L.marker(
#                 [52.206939500000004, 21.07959],
#                 {}
#             ).addTo(map_6de3df385e60494bb42da5520c978a4e);
#
#
#         var popup_3104fed2d0fde8b5b5593d1f672d3740 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d6958923eaaf34673b91653342d4a737 = $(`&lt;div id=&quot;html_d6958923eaaf34673b91653342d4a737&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_3104fed2d0fde8b5b5593d1f672d3740.setContent(html_d6958923eaaf34673b91653342d4a737);
#
#
#
#         marker_9b8f5a82336ac7cae99c05dc0fd4c701.bindPopup(popup_3104fed2d0fde8b5b5593d1f672d3740)
#         ;
#
#
#
#
#             var marker_a07bb40d49ea5282fa3899304361b966 = L.marker(
#                 [52.2145765, 21.092980500000003],
#                 {}
#             ).addTo(map_6de3df385e60494bb42da5520c978a4e);
#
#
#         var popup_da7f68c4be1e2f3301a3f4a8c5e14f15 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b50fa4d888f5902dc186a271750e03c = $(`&lt;div id=&quot;html_7b50fa4d888f5902dc186a271750e03c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_da7f68c4be1e2f3301a3f4a8c5e14f15.setContent(html_7b50fa4d888f5902dc186a271750e03c);
#
#
#
#         marker_a07bb40d49ea5282fa3899304361b966.bindPopup(popup_da7f68c4be1e2f3301a3f4a8c5e14f15)
#         ;
#
#
#
#
#             var marker_9ae8bbbb448b5ed39893580babbcefe9 = L.marker(
#                 [52.2136515, 21.092122],
#                 {}
#             ).addTo(map_6de3df385e60494bb42da5520c978a4e);
#
#
#         var popup_d10b2fa3791c2bee38910c3aca3c65d8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_245d528989d2b81d5a8ef6bdacc176ce = $(`&lt;div id=&quot;html_245d528989d2b81d5a8ef6bdacc176ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;over 60&lt;/div&gt;`)[0];
#                 popup_d10b2fa3791c2bee38910c3aca3c65d8.setContent(html_245d528989d2b81d5a8ef6bdacc176ce);
#
#
#
#         marker_9ae8bbbb448b5ed39893580babbcefe9.bindPopup(popup_d10b2fa3791c2bee38910c3aca3c65d8)
#         ;
#
#
#
#
#             var marker_93d2796a380f21893bf5443d2c766b9b = L.marker(
#                 [52.25041485, 21.14812565],
#                 {}
#             ).addTo(map_6de3df385e60494bb42da5520c978a4e);

# %% [markdown]
# # Places with a lot of high speeds
# ### After 12:38:

# %%
current_locations_bus1.get_locations_with_lots_overspeeds()
# Out:
# There were 7 areas where at least 3 buses exceded the speed limit.
# Map with these places with aproximate high-speed-steets and with informations
#         how many high-speed measurements where in this area:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfe39ae1bb76b85059d339cda1cb0c96 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfe39ae1bb76b85059d339cda1cb0c96&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfe39ae1bb76b85059d339cda1cb0c96 = L.map(
#                 &quot;map_cfe39ae1bb76b85059d339cda1cb0c96&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fadfe2333385c48bb5be15deaa2ac729 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fadfe2333385c48bb5be15deaa2ac729.addTo(map_cfe39ae1bb76b85059d339cda1cb0c96);
#
#
#             var poly_line_8f5ba0c8c0a1a294b87fe43aaaf236ed = L.polyline(
#                 [[52.2964164, 20.93439845], [52.29927835, 20.93816005]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cfe39ae1bb76b85059d339cda1cb0c96);
#
#
#             var poly_line_538358d165edc85d6df74ab881eb2278 = L.polyline(
#                 [[52.29927835, 20.93816005], [52.29907675, 20.9385238]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cfe39ae1bb76b85059d339cda1cb0c96);
#
#
#             var poly_line_0f1c7dba0e021d92b4303d2e71036b81 = L.polyline(
#                 [[52.29907675, 20.9385238], [52.30068795, 20.9416023]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cfe39ae1bb76b85059d339cda1cb0c96);
#
#
#             var poly_line_ac07dd1b7f3400eb32de5a70f932781d = L.polyline(
#                 [[52.30068795, 20.9416023], [52.30211655, 20.9422728]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cfe39ae1bb76b85059d339cda1cb0c96);
#
#
#             var poly_line_04c0423e5e72a40a660d2018384aeb63 = L.polyline(
#                 [[52.30211655, 20.9422728], [52.30403445, 20.9457737]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_cfe39ae1bb76b85059d339cda1cb0c96);
#
#
#             var poly_line_9cb865f175b5f5a4d1c905efc8df037d = L.polyline(
#                 [[52.30403445, 20.9457737], [52.306010150000006, 20.950071649999998]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&q

# %% [markdown]
# ### After 19:50:

# %%
current_locations_bus2.get_locations_with_lots_overspeeds()
# Out:
# There were 13 areas where at least 3 buses exceded the speed limit.
# Map with these places with aproximate high-speed-steets and with informations
#         how many high-speed measurements where in this area:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_580cd4613fa85d341c6821f5591c22c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_580cd4613fa85d341c6821f5591c22c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_580cd4613fa85d341c6821f5591c22c0 = L.map(
#                 &quot;map_580cd4613fa85d341c6821f5591c22c0&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5aa6544d7b31fc150e9261d5ef07f44 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d5aa6544d7b31fc150e9261d5ef07f44.addTo(map_580cd4613fa85d341c6821f5591c22c0);
#
#
#             var poly_line_40c5686d60d6b7732002825ed5f4e3ba = L.polyline(
#                 [[52.1687508335, 21.012320666999997], [52.168828500000004, 21.0135045]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_580cd4613fa85d341c6821f5591c22c0);
#
#
#             var poly_line_7ba127dee9c9a3de88b7f00a20ca6336 = L.polyline(
#                 [[52.168828500000004, 21.0135045], [52.1679015, 21.016933]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_580cd4613fa85d341c6821f5591c22c0);
#
#
#             var poly_line_66aef32502c7bf070df7deba6a8b630d = L.polyline(
#                 [[52.1679015, 21.016933], [52.1618045, 21.0176595]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_580cd4613fa85d341c6821f5591c22c0);
#
#
#             var poly_line_5b1cd36a10088e4a3c6d269a851998c9 = L.polyline(
#                 [[52.1618045, 21.0176595], [52.1605639, 21.01768975]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_580cd4613fa85d341c6821f5591c22c0);
#
#
#             var poly_line_273352c33a64bd7d4a35071b00f9c3c1 = L.polyline(
#                 [[52.1605639, 21.01768975], [52.1589072, 21.0176915]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_580cd4613fa85d341c6821f5591c22c0);
#
#
#             var poly_line_219d2d36e4383a5a09ed7b38a191f3ca = L.polyline(
#                 [[52.1589072, 21.0176915], [52.166767667, 21.02533425]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#2ecc71&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#2ecc71&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&

# %% [markdown]
# # Punctuality:
# ### After 12:38:

# %%
punctuality_object1 = am.get_punctuality_object("2024-02-20, 12:38 ztm", "2024-02-20 schedule")
#punctuality_object1.count_late_buses(True)
punctuality_object1.load_late_buses("out1.csv")
punctuality_object1.analize_delays(4, 0.2, True, True)
# Out:
# Buses were deleyed in 11.58% measured cases.
# Busstops without any delay: 824
# Number of busstops satisfing function's conditions (at least 4 buses): 1532
# Table with the most deleyed busstops:
#      zespol  slupek               nazwa_zespolu   szer_geo   dlug_geo  late  \
# 4676   4038       1  Komitetu Obrony Robotników  52.178995  20.978165     5
# 4789   4085       2                    Radarowa  52.188762  20.962959     7
# 4675   4037       4                     Sasanki  52.184058  20.977725     7
# 3092   3027      52                       Dolna  52.202896  21.034283    11
# 4595   4011       6                       Hynka  52.190608  20.957315     5
# 5003   4200       1     Lotnisko Chopina-Odloty  52.172074  20.973369     5
# 4793   4087       2                   Orzechowa  52.192147  20.949007     4
#
#       all   percent
# 4676    5  1.000000
# 4789    7  1.000000
# 4675    8  0.875000
# 3092   13  0.846154
# 4595    6  0.833333
# 5003    6  0.833333
# 4793    5  0.800000
# Map with delays:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d699741c2ad2e46dd7c11a2ecbadcb0e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d699741c2ad2e46dd7c11a2ecbadcb0e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d699741c2ad2e46dd7c11a2ecbadcb0e = L.map(
#                 &quot;map_d699741c2ad2e46dd7c11a2ecbadcb0e&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e08441a436a2e7e4ca8e5ee2e4323cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2e08441a436a2e7e4ca8e5ee2e4323cf.addTo(map_d699741c2ad2e46dd7c11a2ecbadcb0e);
#
#
#             var circle_marker_e924731c09d0cf60426f6d7da4c6bdb7 = L.circleMarker(
#                 [52.178995, 20.978165],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ba4a00&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d699741c2ad2e46dd7c11a2ecbadcb0e);
#
#
#         var popup_b11d6908f7d553ec6f59af794f573e16 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_07e777408217bbfe686cd1dd5ed68d1b = $(`&lt;div id=&quot;html_07e777408217bbfe686cd1dd5ed68d1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1.0&lt;/div&gt;`)[0];
#                 popup_b11d6908f7d553ec6f59af794f573e16.setContent(html_07e777408217bbfe686cd1dd5ed68d1b);
#
#
#
#         circle_marker_e924731c09d0cf60426f6d7da4c6bdb7.bindPopup(popup_b11d6908f7d553ec6f59af794f573e16)
#         ;
#
#
#
#
#             var circle_marker_0035d316df3601a8da37b735f8839bce = L.circleMarker(
#                 [52.188762, 20.962959],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ba4a00&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d699741c2ad2e46dd7c11a2ecbadcb0e);
#
#
#         var popup_255b147e53cf0c04ae3c5bdb83a2d4fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4064782214d7d63248d72e11e4f369f2 = $(`&lt;div id=&quot;html_4064782214d7d63248d72e11e4f369f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1.0&lt;/div&gt;`)[0];
#                 popup_255b147e53cf0c04ae3c5bdb83a2d4fa.setContent(html_4064782214d7d63248d72e11e4f369f2);
#
#
#
#         circle_marker_0035d316df3601a8da37b735f8839bce.bindPopup(popup_255b147e53cf0c04ae3c5bdb83a2d4fa)
#         ;
#
#
#
#
#             var circle_marker_ff7daffa37f83597ba6727dfd766a0f1 = L.circleMarker(
#                 [52.184058, 20.977725],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d699741c2ad2e46dd7c11a2ecbadcb0e);
#
#
#         var popup_ce2ae52505d91325eb4114824ece4c55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f5818c189dde1e7e50739f47fb823e7 = $(`&lt;div id=&quot;html_6f5818c189dde1e7e50739f47fb823e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.875&lt;/div&gt;`)[0];
#                 popup_ce2ae52505d91325eb4114824ece4c55.setContent(html_6f5818c189dde1e7e50739f47fb823e7);
#
#
#
#         circle_marker_ff7daffa37f83597ba6727dfd766a0f1.bindPopup(popup_ce2ae52505d91325eb4114824ece4c55)
#         ;
#
#
#
#
#             var circle_marker_48447bb3e3b4144a03ba6d1427ce9e03 = L.circleMarker(
#                 [52.202896, 21.034283],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;roun

# %%
punctuality_object1.get_all_busstops()
# Out:
#       Unnamed: 0 zespol  slupek        nazwa_zespolu   szer_geo   dlug_geo  \
# 0              0   1001       1             Kijowska  52.248455  21.044827
# 1              1   1001       2             Kijowska  52.249078  21.044443
# 2              2   1001       3             Kijowska  52.248928  21.044169
# 3              3   1001       4             Kijowska  52.249969  21.041588
# 4              4   1001       5             Kijowska  52.250319  21.043861
# ...          ...    ...     ...                  ...        ...        ...
# 7050        7050   R-11      99       ZEA KLESZCZOWA  52.196605  20.922746
# 7051        7051   R-13       0          ZEA STALOWA  52.263590  21.047868
# 7052        7052   R-13      99          ZEA STALOWA  52.263631  21.047922
# 7053        7053   R-19       0  WYDZIAŁ WŁOŚCIAŃSKA  52.271236  20.968586
# 7054        7054   R-19      99  WYDZIAŁ WŁOŚCIAŃSKA  52.271236  20.968496
#
#       late  all
# 0        0   18
# 1        2    8
# 2        0    0
# 3        0    0
# 4        0    0
# ...    ...  ...
# 7050     0    0
# 7051     0    1
# 7052     0    0
# 7053     0    0
# 7054     0    0
#
# [7055 rows x 8 columns]

# %% [markdown]
# ### After 19:50:

# %%
punctuality_object2 = am.get_punctuality_object("2024-02-20, 19:50 ztm", "2024-02-20 schedule")
#punctuality_object2.count_late_buses(True)
punctuality_object2.load_late_buses("out2.csv")
punctuality_object2.analize_delays(4, 0.5, True, True)
# Out:
# Buses were deleyed in 8.52% measured cases.
# Busstops without any delay: 950
# Number of busstops satisfing function's conditions (at least 4 buses): 1666
# Table with the most deleyed busstops:
#      zespol  slupek         nazwa_zespolu   szer_geo   dlug_geo  late  all  \
# 5234   4348       1   PKP Żwirki i Wigury  52.193570  20.981904     6    8
# 3366   3126       2              Tagore'a  52.195369  21.007382     3    5
# 4100   3701      71                 Zgoda  52.074815  21.029482     3    5
# 3477   3168       1  Kolejka Piaseczyńska  52.069128  21.025004     3    5
# 3700   3255       2            Miłobędzka  52.197028  20.992109     3    5
# 6866   7054       3        Park Traugutta  52.258470  21.002556     3    5
# 6497   6407       2      Łomianki-Centrum  52.339728  20.890891     3    5
#
#       percent
# 5234     0.75
# 3366     0.60
# 4100     0.60
# 3477     0.60
# 3700     0.60
# 6866     0.60
# 6497     0.60
# Map with delays:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_403c63e291aad46b411291acaab015fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_403c63e291aad46b411291acaab015fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_403c63e291aad46b411291acaab015fa = L.map(
#                 &quot;map_403c63e291aad46b411291acaab015fa&quot;,
#                 {
#                     center: [52.22, 21.01],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c625c392163da47c1e92a232c14905de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c625c392163da47c1e92a232c14905de.addTo(map_403c63e291aad46b411291acaab015fa);
#
#
#             var circle_marker_32e103fcd20016935de9d57ccce70ae0 = L.circleMarker(
#                 [52.19357, 20.981904],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_403c63e291aad46b411291acaab015fa);
#
#
#         var popup_3a28f7a3f3738d0ff6b12dd6c9944b13 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_51ef42cb2f6d8b0419603f32b084176f = $(`&lt;div id=&quot;html_51ef42cb2f6d8b0419603f32b084176f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.75&lt;/div&gt;`)[0];
#                 popup_3a28f7a3f3738d0ff6b12dd6c9944b13.setContent(html_51ef42cb2f6d8b0419603f32b084176f);
#
#
#
#         circle_marker_32e103fcd20016935de9d57ccce70ae0.bindPopup(popup_3a28f7a3f3738d0ff6b12dd6c9944b13)
#         ;
#
#
#
#
#             var circle_marker_7b408dc8378bad1e9457bb9da6f03c2c = L.circleMarker(
#                 [52.195369, 21.007382],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_403c63e291aad46b411291acaab015fa);
#
#
#         var popup_2f2759b277fca282f9d247a8889ac41e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d91df1ce68297aa5b3fb49f997d03a6 = $(`&lt;div id=&quot;html_5d91df1ce68297aa5b3fb49f997d03a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.6&lt;/div&gt;`)[0];
#                 popup_2f2759b277fca282f9d247a8889ac41e.setContent(html_5d91df1ce68297aa5b3fb49f997d03a6);
#
#
#
#         circle_marker_7b408dc8378bad1e9457bb9da6f03c2c.bindPopup(popup_2f2759b277fca282f9d247a8889ac41e)
#         ;
#
#
#
#
#             var circle_marker_60f2d7050906ec742b4f9234c877b26b = L.circleMarker(
#                 [52.074815, 21.029482],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_403c63e291aad46b411291acaab015fa);
#
#
#         var popup_c10caaa3eea8eea54192d8ee19162e94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c99dc78551f8b06a8680d679dda3fe06 = $(`&lt;div id=&quot;html_c99dc78551f8b06a8680d679dda3fe06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;0.6&lt;/div&gt;`)[0];
#                 popup_c10caaa3eea8eea54192d8ee19162e94.setContent(html_c99dc78551f8b06a8680d679dda3fe06);
#
#
#
#         circle_marker_60f2d7050906ec742b4f9234c877b26b.bindPopup(popup_c10caaa3eea8eea54192d8ee19162e94)
#         ;
#
#
#
#
#             var circle_marker_4789f1c6c805abfa87a0975d54f0adc5 = L.circleMarker(
#                 [52.069128, 21.025004],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: false, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#e67e22&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&
